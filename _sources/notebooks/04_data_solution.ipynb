# %% [markdown]
# ## Programmatic Data Operations
#
# *Authors: Zach del Rosario*

# %% [markdown]
# The purpose of this exercise is to give you some tools to work with data *programmatically*; that is, using a programming language. While you can carry out many data operations by hand or with spreadsheet programs, you will see that doing things programmatically is extremely powerful.
#
# ### Learning Outcomes
# By working through this notebook, you will be able to:
#
# - Use Pandas' `DataFrame` object to represent data
# - Use DataFrame operations from the package `py-grama` to operate on data

# %%
import numpy as np
import pandas as pd
import grama as gr

DF = gr.Intention()

# For downloading data
import os
import requests

# %% [markdown]
# ## DataFrames
#
# ---

# %% [markdown]
# A `DataFrame` is a data structure provided by Pandas. In contrast with `lists` (which we saw in the previous exercise), DataFrames are explicitly designed to facilitate data analysis. Accordingly, they provide a number of helpful features that aid in data analysis and operations.
#
# A `DataFrame` is a *rectangular* representation of data -- it consists of rows and columns. Each *row* represents an *observation* -- a single instance of data. Each *column* represents a *variable* -- a particular attribute of the observation.

# %% [markdown]
# For instance, the following code chunk downloads a alloy dataset into the DataFrame `df_mpea` -- here each row is an alloy, and each column is some physical property of that alloy.

# %%
# Filename for local data
filename_data = "./data/mpea.csv"

# The following code downloads the data, or (after downloaded)
# loads the data from a cached CSV on your machine
if not os.path.exists(filename_data):
    # Make request for data
    url_data = "https://docs.google.com/spreadsheets/u/1/d/1MsF4_jhWtEuZSvWfXLDHWEqLMScGCVXYWtqHW9Y7Yt0/export?format=csv"
    r = requests.get(url_data, allow_redirects=True)
    open(filename_data, 'wb').write(r.content)
    print("   MPEA data downloaded from public Google sheet")
else:
    # Note data already exists
    print("    MPEA data loaded locally")
    
# Read the data into memory
df_mpea = pd.read_csv(filename_data)
# Out:
#     MPEA data loaded locally

# %% [markdown]
# Let's use some of the basic attributes of the data to get some basic facts:

# %%
# Check the shape
df_mpea.shape
# Out:
# (1653, 20)

# %% [markdown]
# We have `1653` rows (also called observations) on 20 columns (also called variables or features).

# %%
df_mpea.head()
# Out:
#    IDENTIFIER: Reference ID                                      FORMULA  \
# 0                       146                        Cr1 Mo1 Nb1 Ta1 V1 W1
# 1                       146                        Cr1 Mo1 Nb1 Ta1 V1 W1
# 2                       137                              Co1 Cr1 Fe1 Ni1
# 3                        19                          Al1 Cr1 Fe1 Mo1 Ni1
# 4                       155  Al1 Co0.426 Cr0.383 Cu0.106 Fe0.106 Ni0.106
#
#   PROPERTY: Microstructure PROPERTY: Processing method  \
# 0                      NaN                      POWDER
# 1                      NaN                      POWDER
# 2                      FCC                        CAST
# 3                  B2+Sec.                        CAST
# 4                      NaN                         NaN
#
#    PROPERTY: grain size ($\mu$m)  PROPERTY: ROM Density (g/cm$^3$)  \
# 0                           5.01                               NaN
# 1                          10.80                               NaN
# 2                            NaN                               NaN
# 3                            NaN                               7.2
# 4                            NaN                               NaN
#
#    PROPERTY: Exp. Density (g/cm$^3$)  PROPERTY: HV PROPERTY: Type of test  \
# 0                                NaN         991.3                      C
# 1                                NaN         988.3                      C
# 2                                NaN          94.7                    NaN
# 3                                NaN         905.0                    NaN
# 4                                NaN         883.0                    NaN
#
#    PROPERTY: Test temperature ($^\circ$C)  PROPERTY: YS (MPa)  \
# 0                                    25.0              3410.0
# 1                                    25.0              3338.0
# 2                                     NaN                 NaN
# 3                                    25.0                 NaN
# 4                                     NaN                 NaN
#
#    PROPERTY: UTS (MPa)  PROPERTY: Elongation (%)  \
# 0                  NaN                       2.0
# 1                  NaN                       1.9
# 2                  NaN                       NaN
# 3                  NaN                       NaN
# 4                  NaN                       NaN
#
#    PROPERTY: Elongation plastic (%)  PROPERTY: Young modulus (GPa)  \
# 0                               NaN                            NaN
# 1                               NaN                            NaN
# 2                               NaN                            NaN
# 3                               NaN                            NaN
# 4                               NaN                            NaN
#
#    PROPERTY: O content (wppm) PROPERTY: N content (wppm)  \
# 0                      7946.0                        NaN
# 1                      7946.0                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
#
#    PROPERTY: C content (wppm)                 REFERENCE: doi  REFERENCE: year
# 0                         NaN  10.1016/j.jallcom.2018.11.318             2018
# 1                         NaN  10.1016/j.jallcom.2018.11.318             2018
# 2                         NaN   10.1016/j.matdes.2019.107698             2019
# 3                         NaN  10.1016/j.jallcom.2013.03.253             2013
# 4                         NaN  10.1016/j.actamat.2019.03.010             2019

# %% [markdown]
# The `head` method shows just the top of the DataFrame; this is useful for "getting a sense" for what's in the data.

# %%
df_mpea.dtypes
# Out:
# IDENTIFIER: Reference ID                    int64
# FORMULA                                    object
# PROPERTY: Microstructure                   object
# PROPERTY: Processing method                object
# PROPERTY: grain size ($\mu$m)             float64
# PROPERTY: ROM Density (g/cm$^3$)          float64
# PROPERTY: Exp. Density (g/cm$^3$)         float64
# PROPERTY: HV                              float64
# PROPERTY: Type of test                     object
# PROPERTY: Test temperature ($^\circ$C)    float64
# PROPERTY: YS (MPa)                        float64
# PROPERTY: UTS (MPa)                       float64
# PROPERTY: Elongation (%)                  float64
# PROPERTY: Elongation plastic (%)          float64
# PROPERTY: Young modulus (GPa)             float64
# PROPERTY: O content (wppm)                float64
# PROPERTY: N content (wppm)                 object
# PROPERTY: C content (wppm)                float64
# REFERENCE: doi                             object
# REFERENCE: year                             int64
# dtype: object

# %% [markdown]
# The `dtypes` attribute gives us the data type for each column. Depending on the dataset, you might find that your data loads in with strange datatypes. This can happen, for instance, if your numeric values are contained within string characters (e.g. `"1.23"`). If this happens, you can catch the fact with a call to `df_data.dtypes`.

# %% [markdown]
# ### __Q1__: Inspecting a DataFrame
# Consult the [pandas documentation](https://pandas.pydata.org/pandas-docs/stable/getting_started/10min.html) (it might be useful to use a page search) and use some basic calls on `df_mpea` to answer the following questions:
#
# - What are the *last* five observations in the DataFrame?
# - How many rows are in `df_mpea`? How many columns?
# - How would you access the column `PROPERTY: Microstructure`?

# %%
###
# TASK: Inspect df_data
# TODO: Show the last five observations of df_mpea
###

# -- WRITE YOUR CODE BELOW -----
df_mpea.tail(5)
# Out:
#       IDENTIFIER: Reference ID               FORMULA PROPERTY: Microstructure  \
# 1648                       132   Hf1 Nb1 Ta1 Ti1 Zr1                      BCC
# 1649                       132   Hf1 Nb1 Ta1 Ti1 Zr1                      BCC
# 1650                       132   Hf1 Nb1 Ta1 Ti1 Zr1                      BCC
# 1651                       133  Al1 Nb1 Ti1 V1 Zr0.5                      NaN
# 1652                       133       Hf1 Nb1 Ti1 Zr1                      NaN
#
#      PROPERTY: Processing method  PROPERTY: grain size ($\mu$m)  \
# 1648                       OTHER                           50.1
# 1649                       OTHER                           21.9
# 1650                       OTHER                           75.5
# 1651                         NaN                            NaN
# 1652                         NaN                            NaN
#
#       PROPERTY: ROM Density (g/cm$^3$)  PROPERTY: Exp. Density (g/cm$^3$)  \
# 1648                               NaN                                NaN
# 1649                               NaN                                NaN
# 1650                               NaN                                NaN
# 1651                               NaN                               5.64
# 1652                               NaN                                NaN
#
#       PROPERTY: HV PROPERTY: Type of test  \
# 1648           NaN                    NaN
# 1649           NaN                    NaN
# 1650           NaN                    NaN
# 1651           NaN                      C
# 1652           NaN                      C
#
#       PROPERTY: Test temperature ($^\circ$C)  PROPERTY: YS (MPa)  \
# 1648                                     NaN                 NaN
# 1649                                     NaN                 NaN
# 1650                                     NaN                 NaN
# 1651                                    25.0              1480.0
# 1652                                    25.0               879.0
#
#       PROPERTY: UTS (MPa)  PROPERTY: Elongation (%)  \
# 1648                  NaN                       NaN
# 1649                  NaN                       NaN
# 1650                  NaN                       NaN
# 1651                  NaN                      50.0
# 1652                  NaN                      16.5
#
#       PROPERTY: Elongation plastic (%)  PROPERTY: Young modulus (GPa)  \
# 1648                               NaN                            NaN
# 1649                               NaN                            NaN
# 1650                               NaN                            NaN
# 1651                               NaN                            NaN
# 1652                               NaN                            NaN
#
#       PROPERTY: O content (wppm) PROPERTY: N content (wppm)  \
# 1648                         NaN                        NaN
# 1649                         NaN                        NaN
# 1650                         NaN                        NaN
# 1651                         NaN                        NaN
# 1652                         NaN                        NaN
#
#       PROPERTY: C content (wppm)                 REFERENCE: doi  \
# 1648                         NaN      10.1007/s11661-018-4646-8
# 1649                         NaN      10.1007/s11661-018-4646-8
# 1650                         NaN      10.1007/s11661-018-4646-8
# 1651                         NaN  10.1080/02670836.2018.1446267
# 1652                         NaN  10.1080/02670836.2018.1446267
#
#       REFERENCE: year
# 1648             2019
# 1649             2019
# 1650             2019
# 1651             2018
# 1652             2018

# %%
###
# TASK: Inspect df_mpea
# TODO: Determine the number of rows and columns in df_mpea
###

# -- WRITE YOUR CODE BELOW -----
df_mpea.shape  # rows, columns
# Out:
# (1653, 20)

# %%
###
# TASK: Inspect df_data
# TODO: Grab the column `PROPERTY: Microstructure` alone
###

# -- WRITE YOUR CODE BELOW -----
# Note that this returns a Pandas Series
df_mpea["PROPERTY: Microstructure"]
# And this returns a Pandas DataFrame
df_mpea[["PROPERTY: Microstructure"]]
# Out:
#      PROPERTY: Microstructure
# 0                         NaN
# 1                         NaN
# 2                         FCC
# 3                     B2+Sec.
# 4                         NaN
# ...                       ...
# 1648                      BCC
# 1649                      BCC
# 1650                      BCC
# 1651                      NaN
# 1652                      NaN
#
# [1653 rows x 1 columns]

# %% [markdown]
# These manipulations are simple, but they are bread-and-butter for studying new datasets.

# %% [markdown]
# ## Grama
#
# ---
#
# The `py-grama` package builds on top of Pandas to provide a pipeline-based data (and model) infrastructure. Grama provides many of the same functions as Pandas (really, just different ways to use the same Pandas functions):

# %%
(
   df_mpea
   >> gr.tf_head()
)
# Out:
#    IDENTIFIER: Reference ID                                      FORMULA  \
# 0                       146                        Cr1 Mo1 Nb1 Ta1 V1 W1
# 1                       146                        Cr1 Mo1 Nb1 Ta1 V1 W1
# 2                       137                              Co1 Cr1 Fe1 Ni1
# 3                        19                          Al1 Cr1 Fe1 Mo1 Ni1
# 4                       155  Al1 Co0.426 Cr0.383 Cu0.106 Fe0.106 Ni0.106
#
#   PROPERTY: Microstructure PROPERTY: Processing method  \
# 0                      NaN                      POWDER
# 1                      NaN                      POWDER
# 2                      FCC                        CAST
# 3                  B2+Sec.                        CAST
# 4                      NaN                         NaN
#
#    PROPERTY: grain size ($\mu$m)  PROPERTY: ROM Density (g/cm$^3$)  \
# 0                           5.01                               NaN
# 1                          10.80                               NaN
# 2                            NaN                               NaN
# 3                            NaN                               7.2
# 4                            NaN                               NaN
#
#    PROPERTY: Exp. Density (g/cm$^3$)  PROPERTY: HV PROPERTY: Type of test  \
# 0                                NaN         991.3                      C
# 1                                NaN         988.3                      C
# 2                                NaN          94.7                    NaN
# 3                                NaN         905.0                    NaN
# 4                                NaN         883.0                    NaN
#
#    PROPERTY: Test temperature ($^\circ$C)  PROPERTY: YS (MPa)  \
# 0                                    25.0              3410.0
# 1                                    25.0              3338.0
# 2                                     NaN                 NaN
# 3                                    25.0                 NaN
# 4                                     NaN                 NaN
#
#    PROPERTY: UTS (MPa)  PROPERTY: Elongation (%)  \
# 0                  NaN                       2.0
# 1                  NaN                       1.9
# 2                  NaN                       NaN
# 3                  NaN                       NaN
# 4                  NaN                       NaN
#
#    PROPERTY: Elongation plastic (%)  PROPERTY: Young modulus (GPa)  \
# 0                               NaN                            NaN
# 1                               NaN                            NaN
# 2                               NaN                            NaN
# 3                               NaN                            NaN
# 4                               NaN                            NaN
#
#    PROPERTY: O content (wppm) PROPERTY: N content (wppm)  \
# 0                      7946.0                        NaN
# 1                      7946.0                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
#
#    PROPERTY: C content (wppm)                 REFERENCE: doi  REFERENCE: year
# 0                         NaN  10.1016/j.jallcom.2018.11.318             2018
# 1                         NaN  10.1016/j.jallcom.2018.11.318             2018
# 2                         NaN   10.1016/j.matdes.2019.107698             2019
# 3                         NaN  10.1016/j.jallcom.2013.03.253             2013
# 4                         NaN  10.1016/j.actamat.2019.03.010             2019

# %% [markdown]
# One of the advantages of using `py-grama` is that we can write *data pipelines* to organize our data operations. For instance, the following code filters the MPEA dataset to only those cases that have a valid Yield Strength (YS) and Ultimate Tensile Strength (UTS), and computes a correlation coefficient between those two quantities.

# %%
## NOTE: No need to edit; run and see the result
(
    df_mpea
    >> gr.tf_filter(
        gr.not_nan(DF["PROPERTY: YS (MPa)"]),
        gr.not_nan(DF["PROPERTY: UTS (MPa)"]),
    )
    >> gr.tf_summarize(
        rho_YS_UTS=gr.corr(
            DF["PROPERTY: YS (MPa)"],
            DF["PROPERTY: UTS (MPa)"],
        )
    )
)
# Out:
#    rho_YS_UTS
# 0    0.870465

# %% [markdown]
# As we might expect, these two properties are strongly correlated.
#
# This code shows off a few concepts, which we'll explore below: The pipe operator `>>`, Grama verbs (such as `tf_filter`), and the data pronoun `DF`.

# %% [markdown]
# ### The pipe operator `>>`
#
# It's helpful to think of the pipe operator `>>` as the words "and then". That means code like this:
#
# ```
# (
#     df_mpea
#     >> gr.tf_filter( ... )
#     >> gr.tf_mutate( ... )
#     >> gr.tf_pivot_longer( ... )
# )
# ```
#
# Can be read something like an English sentence, where we are using various *verbs* to operate on the data:
#
# ```
# (
#     Start with df_mpea
#     and then filter the data
#     and then mutate the data
#     and then pivot the data in to a longer format
# )
# ```
#
# We don't yet know what these verbs do; we'll learn more in the exercises below!

# %% [markdown]
# ### Selecting
#
# The `tf_select` verb allows us to select one or more columns; this is helpful when we want to focus on just a handful of properties, such as the chemical formulas.

# %%
(
    df_mpea
    >> gr.tf_select("FORMULA")
)
# Out:
#                                           FORMULA
# 0                           Cr1 Mo1 Nb1 Ta1 V1 W1
# 1                           Cr1 Mo1 Nb1 Ta1 V1 W1
# 2                                 Co1 Cr1 Fe1 Ni1
# 3                             Al1 Cr1 Fe1 Mo1 Ni1
# 4     Al1 Co0.426 Cr0.383 Cu0.106 Fe0.106 Ni0.106
# ...                                           ...
# 1648                          Hf1 Nb1 Ta1 Ti1 Zr1
# 1649                          Hf1 Nb1 Ta1 Ti1 Zr1
# 1650                          Hf1 Nb1 Ta1 Ti1 Zr1
# 1651                         Al1 Nb1 Ti1 V1 Zr0.5
# 1652                              Hf1 Nb1 Ti1 Zr1
#
# [1653 rows x 1 columns]

# %% [markdown]
# ### __qX__ Use `tf_select` to select the formula and microstructure columns only.

# %%
###
# TASK: Select the formula and microstructure columns only
###

# -- WRITE YOUR CODE BELOW -----
(
    df_mpea
    >> gr.tf_select("FORMULA", "PROPERTY: Microstructure")
)
# solution-end
# Out:
#                                           FORMULA PROPERTY: Microstructure
# 0                           Cr1 Mo1 Nb1 Ta1 V1 W1                      NaN
# 1                           Cr1 Mo1 Nb1 Ta1 V1 W1                      NaN
# 2                                 Co1 Cr1 Fe1 Ni1                      FCC
# 3                             Al1 Cr1 Fe1 Mo1 Ni1                  B2+Sec.
# 4     Al1 Co0.426 Cr0.383 Cu0.106 Fe0.106 Ni0.106                      NaN
# ...                                           ...                      ...
# 1648                          Hf1 Nb1 Ta1 Ti1 Zr1                      BCC
# 1649                          Hf1 Nb1 Ta1 Ti1 Zr1                      BCC
# 1650                          Hf1 Nb1 Ta1 Ti1 Zr1                      BCC
# 1651                         Al1 Nb1 Ti1 V1 Zr0.5                      NaN
# 1652                              Hf1 Nb1 Ti1 Zr1                      NaN
#
# [1653 rows x 2 columns]

# %% [markdown]
# We can also use some *selection helpers* to make `tf_select` even more convenient. For instance, the `gr.everything()` function just selects all the columns, which at first seems silly:

# %%
(
    df_mpea
    >> gr.tf_select(gr.everything())
    >> gr.tf_head()
)
# Out:
#    IDENTIFIER: Reference ID                                      FORMULA  \
# 0                       146                        Cr1 Mo1 Nb1 Ta1 V1 W1
# 1                       146                        Cr1 Mo1 Nb1 Ta1 V1 W1
# 2                       137                              Co1 Cr1 Fe1 Ni1
# 3                        19                          Al1 Cr1 Fe1 Mo1 Ni1
# 4                       155  Al1 Co0.426 Cr0.383 Cu0.106 Fe0.106 Ni0.106
#
#   PROPERTY: Microstructure PROPERTY: Processing method  \
# 0                      NaN                      POWDER
# 1                      NaN                      POWDER
# 2                      FCC                        CAST
# 3                  B2+Sec.                        CAST
# 4                      NaN                         NaN
#
#    PROPERTY: grain size ($\mu$m)  PROPERTY: ROM Density (g/cm$^3$)  \
# 0                           5.01                               NaN
# 1                          10.80                               NaN
# 2                            NaN                               NaN
# 3                            NaN                               7.2
# 4                            NaN                               NaN
#
#    PROPERTY: Exp. Density (g/cm$^3$)  PROPERTY: HV PROPERTY: Type of test  \
# 0                                NaN         991.3                      C
# 1                                NaN         988.3                      C
# 2                                NaN          94.7                    NaN
# 3                                NaN         905.0                    NaN
# 4                                NaN         883.0                    NaN
#
#    PROPERTY: Test temperature ($^\circ$C)  PROPERTY: YS (MPa)  \
# 0                                    25.0              3410.0
# 1                                    25.0              3338.0
# 2                                     NaN                 NaN
# 3                                    25.0                 NaN
# 4                                     NaN                 NaN
#
#    PROPERTY: UTS (MPa)  PROPERTY: Elongation (%)  \
# 0                  NaN                       2.0
# 1                  NaN                       1.9
# 2                  NaN                       NaN
# 3                  NaN                       NaN
# 4                  NaN                       NaN
#
#    PROPERTY: Elongation plastic (%)  PROPERTY: Young modulus (GPa)  \
# 0                               NaN                            NaN
# 1                               NaN                            NaN
# 2                               NaN                            NaN
# 3                               NaN                            NaN
# 4                               NaN                            NaN
#
#    PROPERTY: O content (wppm) PROPERTY: N content (wppm)  \
# 0                      7946.0                        NaN
# 1                      7946.0                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
#
#    PROPERTY: C content (wppm)                 REFERENCE: doi  REFERENCE: year
# 0                         NaN  10.1016/j.jallcom.2018.11.318             2018
# 1                         NaN  10.1016/j.jallcom.2018.11.318             2018
# 2                         NaN   10.1016/j.matdes.2019.107698             2019
# 3                         NaN  10.1016/j.jallcom.2013.03.253             2013
# 4                         NaN  10.1016/j.actamat.2019.03.010             2019

# %% [markdown]
# However, when we use `gr.everything()` *along* with specific columns, we can *re-arrange* the columns to make quick comparisons easier. For instance, let's move the reference information to the left. We could then easily copy the DOI's to find the original reference for each observation.

# %%
(
    df_mpea
    >> gr.tf_select("REFERENCE: doi", gr.everything())
    >> gr.tf_head()
)
# Out:
#                   REFERENCE: doi  IDENTIFIER: Reference ID  \
# 0  10.1016/j.jallcom.2018.11.318                       146
# 1  10.1016/j.jallcom.2018.11.318                       146
# 2   10.1016/j.matdes.2019.107698                       137
# 3  10.1016/j.jallcom.2013.03.253                        19
# 4  10.1016/j.actamat.2019.03.010                       155
#
#                                        FORMULA PROPERTY: Microstructure  \
# 0                        Cr1 Mo1 Nb1 Ta1 V1 W1                      NaN
# 1                        Cr1 Mo1 Nb1 Ta1 V1 W1                      NaN
# 2                              Co1 Cr1 Fe1 Ni1                      FCC
# 3                          Al1 Cr1 Fe1 Mo1 Ni1                  B2+Sec.
# 4  Al1 Co0.426 Cr0.383 Cu0.106 Fe0.106 Ni0.106                      NaN
#
#   PROPERTY: Processing method  PROPERTY: grain size ($\mu$m)  \
# 0                      POWDER                           5.01
# 1                      POWDER                          10.80
# 2                        CAST                            NaN
# 3                        CAST                            NaN
# 4                         NaN                            NaN
#
#    PROPERTY: ROM Density (g/cm$^3$)  PROPERTY: Exp. Density (g/cm$^3$)  \
# 0                               NaN                                NaN
# 1                               NaN                                NaN
# 2                               NaN                                NaN
# 3                               7.2                                NaN
# 4                               NaN                                NaN
#
#    PROPERTY: HV PROPERTY: Type of test  \
# 0         991.3                      C
# 1         988.3                      C
# 2          94.7                    NaN
# 3         905.0                    NaN
# 4         883.0                    NaN
#
#    PROPERTY: Test temperature ($^\circ$C)  PROPERTY: YS (MPa)  \
# 0                                    25.0              3410.0
# 1                                    25.0              3338.0
# 2                                     NaN                 NaN
# 3                                    25.0                 NaN
# 4                                     NaN                 NaN
#
#    PROPERTY: UTS (MPa)  PROPERTY: Elongation (%)  \
# 0                  NaN                       2.0
# 1                  NaN                       1.9
# 2                  NaN                       NaN
# 3                  NaN                       NaN
# 4                  NaN                       NaN
#
#    PROPERTY: Elongation plastic (%)  PROPERTY: Young modulus (GPa)  \
# 0                               NaN                            NaN
# 1                               NaN                            NaN
# 2                               NaN                            NaN
# 3                               NaN                            NaN
# 4                               NaN                            NaN
#
#    PROPERTY: O content (wppm) PROPERTY: N content (wppm)  \
# 0                      7946.0                        NaN
# 1                      7946.0                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
#
#    PROPERTY: C content (wppm)  REFERENCE: year
# 0                         NaN             2018
# 1                         NaN             2018
# 2                         NaN             2019
# 3                         NaN             2013
# 4                         NaN             2019

# %% [markdown]
# There are a variety of other selection helpers, including:
#
# - `gr.starts_with(...)` will select all columns that start with a given string
# - `gr.ends_with(...)` will select all columns that end with a given string
# - `gr.contains(...)` will select all columns that contain a given string
# - `gr.matches(...)` will select all columns that match a given [regular expression](https://regexone.com/)
#
# You'll practice using selection helpers in the next task.

# %% [markdown]
# ### __qX__ Use a selection helper to find **all** of the columns with the string `"REFERENCE"`

# %%
###
# TASK: Select the formula and microstructure columns only
###

# -- WRITE YOUR CODE BELOW -----
(
    df_mpea
    >> gr.tf_select(gr.contains("REFERENCE"))
)
# solution-end
# Out:
#                      REFERENCE: doi  REFERENCE: year
# 0     10.1016/j.jallcom.2018.11.318             2018
# 1     10.1016/j.jallcom.2018.11.318             2018
# 2      10.1016/j.matdes.2019.107698             2019
# 3     10.1016/j.jallcom.2013.03.253             2013
# 4     10.1016/j.actamat.2019.03.010             2019
# ...                             ...              ...
# 1648      10.1007/s11661-018-4646-8             2019
# 1649      10.1007/s11661-018-4646-8             2019
# 1650      10.1007/s11661-018-4646-8             2019
# 1651  10.1080/02670836.2018.1446267             2018
# 1652  10.1080/02670836.2018.1446267             2018
#
# [1653 rows x 2 columns]

# %% [markdown]
# ### Renaming
#
# Aside from selecting columns, we can also make convenience modifications to the data. The verb `tf_rename` allows us to rename columns, usually to create a more compact, convenient name:

# %%
## NOTE: No need to edit
(
    df_mpea
    >> gr.tf_rename(
        microstructure="PROPERTY: Microstructure",
    )
    >> gr.tf_head()
)
# Out:
#    IDENTIFIER: Reference ID                                      FORMULA  \
# 0                       146                        Cr1 Mo1 Nb1 Ta1 V1 W1
# 1                       146                        Cr1 Mo1 Nb1 Ta1 V1 W1
# 2                       137                              Co1 Cr1 Fe1 Ni1
# 3                        19                          Al1 Cr1 Fe1 Mo1 Ni1
# 4                       155  Al1 Co0.426 Cr0.383 Cu0.106 Fe0.106 Ni0.106
#
#   microstructure PROPERTY: Processing method  PROPERTY: grain size ($\mu$m)  \
# 0            NaN                      POWDER                           5.01
# 1            NaN                      POWDER                          10.80
# 2            FCC                        CAST                            NaN
# 3        B2+Sec.                        CAST                            NaN
# 4            NaN                         NaN                            NaN
#
#    PROPERTY: ROM Density (g/cm$^3$)  PROPERTY: Exp. Density (g/cm$^3$)  \
# 0                               NaN                                NaN
# 1                               NaN                                NaN
# 2                               NaN                                NaN
# 3                               7.2                                NaN
# 4                               NaN                                NaN
#
#    PROPERTY: HV PROPERTY: Type of test  \
# 0         991.3                      C
# 1         988.3                      C
# 2          94.7                    NaN
# 3         905.0                    NaN
# 4         883.0                    NaN
#
#    PROPERTY: Test temperature ($^\circ$C)  PROPERTY: YS (MPa)  \
# 0                                    25.0              3410.0
# 1                                    25.0              3338.0
# 2                                     NaN                 NaN
# 3                                    25.0                 NaN
# 4                                     NaN                 NaN
#
#    PROPERTY: UTS (MPa)  PROPERTY: Elongation (%)  \
# 0                  NaN                       2.0
# 1                  NaN                       1.9
# 2                  NaN                       NaN
# 3                  NaN                       NaN
# 4                  NaN                       NaN
#
#    PROPERTY: Elongation plastic (%)  PROPERTY: Young modulus (GPa)  \
# 0                               NaN                            NaN
# 1                               NaN                            NaN
# 2                               NaN                            NaN
# 3                               NaN                            NaN
# 4                               NaN                            NaN
#
#    PROPERTY: O content (wppm) PROPERTY: N content (wppm)  \
# 0                      7946.0                        NaN
# 1                      7946.0                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
#
#    PROPERTY: C content (wppm)                 REFERENCE: doi  REFERENCE: year
# 0                         NaN  10.1016/j.jallcom.2018.11.318             2018
# 1                         NaN  10.1016/j.jallcom.2018.11.318             2018
# 2                         NaN   10.1016/j.matdes.2019.107698             2019
# 3                         NaN  10.1016/j.jallcom.2013.03.253             2013
# 4                         NaN  10.1016/j.actamat.2019.03.010             2019

# %% [markdown]
# This is a good time to step aside from verbs to talk about the *data pronoun*.

# %% [markdown]
# ## Interlude: Pipelines and the "Data Pronoun
#
# ---

# %% [markdown]
# (Illustrate the use of the data pronoun)
#
# Imagine we wanted to search through the dataset to find only those materials with a FCC microstructure. Above, we gave the `microstructure` column a new, convenient name. We might like to use that new, convenient name when searching for FCC materials. However, we're going to run into an issue:

# %%
## NOTE: Try uncommenting and running the following code; it WILL break!
# (
#     df_mpea
#     >> gr.tf_rename(
#         microstructure="PROPERTY: Microstructure",
#     )
#     >> gr.tf_filter(
#         df_mpea["microstructure"] == "FCC"
#     )
# )

# %% [markdown]
# If we want to refer to the data *now*---as it is currently in the pipeline---we need a name to refer to that DataFrame. This is where the *data pronoun* comes in; remember when we ran this line way up above in the setup chunk?
#
# ```
# DF = gr.Intention()
# ```
#
# This assigns the data pronoun to the name `DF`. The data pronoun represents a DataFrame, so we can use things like column access `DF["column name"]`. We can use this to take advantage of the new (shorter) name we gave to the microstructure column:

# %%
(
    df_mpea
    >> gr.tf_rename(
        microstructure="PROPERTY: Microstructure",
    )
    >> gr.tf_filter(
        DF["microstructure"] == "FCC"
    )
)
# Out:
#      IDENTIFIER: Reference ID                        FORMULA microstructure  \
# 0                         137                Co1 Cr1 Fe1 Ni1            FCC
# 1                         209        Al0.5 Co1 Fe1 Ni1 Ti0.5            FCC
# 2                         120            Co1 Cr1 Cu1 Ni1 Zn1            FCC
# 3                          35                Al1 Cu1 Ni1 Ti1            FCC
# 4                         130  C0.429 Co1 Cr1 Fe1 Ni1 W0.429            FCC
# ..                        ...                            ...            ...
# 272                       119            Co1 Cr1 Cu1 Fe1 Ni1            FCC
# 273                       120            Co1 Cr1 Cu1 Ni1 Zn1            FCC
# 274                       120            Co1 Cr1 Cu1 Ni1 Zn1            FCC
# 275                       120            Co1 Cr1 Cu1 Ni1 Zn1            FCC
# 276                       130                Co1 Cr1 Fe1 Ni1            FCC
#
#     PROPERTY: Processing method  PROPERTY: grain size ($\mu$m)  \
# 0                          CAST                            NaN
# 1                           NaN                            NaN
# 2                        POWDER                       500.0000
# 3                          CAST                            NaN
# 4                        POWDER                         0.0182
# ..                          ...                            ...
# 272                        CAST                            NaN
# 273                      POWDER                       500.0000
# 274                      POWDER                       500.0000
# 275                      POWDER                       500.0000
# 276                      POWDER                         0.0276
#
#      PROPERTY: ROM Density (g/cm$^3$)  PROPERTY: Exp. Density (g/cm$^3$)  \
# 0                                 NaN                                NaN
# 1                                 NaN                                NaN
# 2                                 NaN                               7.89
# 3                                 5.7                                NaN
# 4                                 NaN                               8.39
# ..                                ...                                ...
# 272                               NaN                                NaN
# 273                               NaN                               5.26
# 274                               NaN                               6.26
# 275                               NaN                               7.84
# 276                               NaN                                NaN
#
#      PROPERTY: HV PROPERTY: Type of test  \
# 0            94.7                    NaN
# 1           733.0                    NaN
# 2           615.0                      C
# 3           537.0                      C
# 4           531.0                    NaN
# ..            ...                    ...
# 272           NaN                      C
# 273           NaN                      C
# 274           NaN                      C
# 275           NaN                      C
# 276           NaN                    NaN
#
#      PROPERTY: Test temperature ($^\circ$C)  PROPERTY: YS (MPa)  \
# 0                                       NaN                 NaN
# 1                                       NaN                 NaN
# 2                                      25.0                 NaN
# 3                                      25.0               300.0
# 4                                       NaN                 NaN
# ..                                      ...                 ...
# 272                                    25.0               300.0
# 273                                    25.0                 NaN
# 274                                    25.0                 NaN
# 275                                    25.0                 NaN
# 276                                     NaN                 NaN
#
#      PROPERTY: UTS (MPa)  PROPERTY: Elongation (%)  \
# 0                    NaN                       NaN
# 1                    NaN                       NaN
# 2                    NaN                       NaN
# 3                  536.0                       NaN
# 4                    NaN                       NaN
# ..                   ...                       ...
# 272                  NaN                      50.2
# 273                  NaN                       NaN
# 274                  NaN                       NaN
# 275                  NaN                       NaN
# 276                  NaN                       NaN
#
#      PROPERTY: Elongation plastic (%)  PROPERTY: Young modulus (GPa)  \
# 0                                 NaN                            NaN
# 1                                 NaN                            NaN
# 2                                 NaN                            NaN
# 3                                0.85                          108.0
# 4                                 NaN                            NaN
# ..                                ...                            ...
# 272                               NaN                            NaN
# 273                               NaN                            NaN
# 274                               NaN                            NaN
# 275                               NaN                            NaN
# 276                               NaN                            NaN
#
#      PROPERTY: O content (wppm) PROPERTY: N content (wppm)  \
# 0                           NaN                        NaN
# 1                           NaN                        NaN
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                           NaN                        NaN
# ..                          ...                        ...
# 272                         NaN                        NaN
# 273                         NaN                        NaN
# 274                         NaN                        NaN
# 275                         NaN                        NaN
# 276                         NaN                        NaN
#
#      PROPERTY: C content (wppm)                REFERENCE: doi  REFERENCE: year
# 0                           NaN  10.1016/j.matdes.2019.107698             2019
# 1                           NaN    10.1016/j.msea.2019.05.056             2019
# 2                           NaN             10.3390/e21020122             2019
# 3                           NaN  10.1016/j.apsusc.2015.07.207             2015
# 4                           NaN       10.3390/coatings9010016             2019
# ..                          ...                           ...              ...
# 272                         NaN     10.1007/s11665-018-3837-1             2019
# 273                         NaN             10.3390/e21020122             2019
# 274                         NaN             10.3390/e21020122             2019
# 275                         NaN             10.3390/e21020122             2019
# 276                         NaN       10.3390/coatings9010016             2019
#
# [277 rows x 20 columns]

# %% [markdown]
# Together, the pipe operator `>>` and the data pronoun `DF` form a powerful team that helps us do sophisticated data operations.

# %% [markdown]
# ### __qX__

# %%
###
# TASK: Eliminate the intermediate variables by using the data pronoun
###

# -- NO NEED TO EDIT; REWRITE THIS CODE -----
# Set up a simple dataset
df_initial = gr.df_make(
    A=[1, 2, 3],
    longcolumnname=[4, 5, 6],
)
print(df_initial)

df_new = (
    df_initial
    >> gr.tf_rename(B="longcolumnname")
)

(
    df_new
    >> gr.tf_filter(df_new.B == 5)
)

# -- WRITE YOUR CODE BELOW -----
(
    df_initial

    >> gr.tf_rename(B="longcolumnname")
    >> gr.tf_filter(DF.B == 5)
)
# Out:
#    A  longcolumnname
# 0  1               4
# 1  2               5
# 2  3               6
#    A  B
# 0  2  5

# %% [markdown]
# ## Back to Verbs
#
# ---

# %% [markdown]
# ### Filtering
#
# We saw `tf_filter` above; this allows us to filter a dataset to only those rows satisfying some logical criterion. This makes answering basic questions about the data very easy. For instance, we might be interested in a particular processing method; we could find only those rows matching a specified method:

# %%
## NOTE: No need to edit
(
    df_mpea
    >> gr.tf_filter(DF["PROPERTY: Processing method"] == "POWDER")
)
# Out:
#      IDENTIFIER: Reference ID                   FORMULA  \
# 0                         146     Cr1 Mo1 Nb1 Ta1 V1 W1
# 1                         146     Cr1 Mo1 Nb1 Ta1 V1 W1
# 2                         191            Mo1 Nb1 Ta1 W1
# 3                          71       Cr1 Ta1 Ti0.3 V1 W1
# 4                         110  Al1 Cr1 Cu1 Fe1 Mn1 W0.5
# ..                        ...                       ...
# 98                        120       Co1 Cr1 Cu1 Ni1 Zn1
# 99                        120       Co1 Cr1 Cu1 Ni1 Zn1
# 100                       120       Co1 Cr1 Cu1 Ni1 Zn1
# 101                       124    Al1 C1 Co1 Cr1 Fe1 Ni1
# 102                       130           Co1 Cr1 Fe1 Ni1
#
#     PROPERTY: Microstructure PROPERTY: Processing method  \
# 0                        NaN                      POWDER
# 1                        NaN                      POWDER
# 2                        BCC                      POWDER
# 3                  BCC+Laves                      POWDER
# 4                        NaN                      POWDER
# ..                       ...                         ...
# 98                       FCC                      POWDER
# 99                       FCC                      POWDER
# 100                      FCC                      POWDER
# 101                      NaN                      POWDER
# 102                      FCC                      POWDER
#
#      PROPERTY: grain size ($\mu$m)  PROPERTY: ROM Density (g/cm$^3$)  \
# 0                           5.0100                               NaN
# 1                          10.8000                               NaN
# 2                              NaN                               NaN
# 3                              NaN                              12.2
# 4                              NaN                               NaN
# ..                             ...                               ...
# 98                        500.0000                               NaN
# 99                        500.0000                               NaN
# 100                       500.0000                               NaN
# 101                            NaN                               NaN
# 102                         0.0276                               NaN
#
#      PROPERTY: Exp. Density (g/cm$^3$)  PROPERTY: HV PROPERTY: Type of test  \
# 0                                  NaN         991.3                      C
# 1                                  NaN         988.3                      C
# 2                                  NaN         830.0                    NaN
# 3                                  NaN         780.0                      C
# 4                                  NaN         780.0                      C
# ..                                 ...           ...                    ...
# 98                                5.26           NaN                      C
# 99                                6.26           NaN                      C
# 100                               7.84           NaN                      C
# 101                                NaN           NaN                    NaN
# 102                                NaN           NaN                    NaN
#
#      PROPERTY: Test temperature ($^\circ$C)  PROPERTY: YS (MPa)  \
# 0                                      25.0              3410.0
# 1                                      25.0              3338.0
# 2                                       NaN                 NaN
# 3                                      25.0              2050.0
# 4                                      25.0              1510.0
# ..                                      ...                 ...
# 98                                     25.0                 NaN
# 99                                     25.0                 NaN
# 100                                    25.0                 NaN
# 101                                     NaN                 NaN
# 102                                     NaN                 NaN
#
#      PROPERTY: UTS (MPa)  PROPERTY: Elongation (%)  \
# 0                    NaN                       2.0
# 1                    NaN                       1.9
# 2                    NaN                       NaN
# 3                    NaN                       1.5
# 4                    NaN                       NaN
# ..                   ...                       ...
# 98                   NaN                       NaN
# 99                   NaN                       NaN
# 100                  NaN                       NaN
# 101                  NaN                       NaN
# 102                  NaN                       NaN
#
#      PROPERTY: Elongation plastic (%)  PROPERTY: Young modulus (GPa)  \
# 0                                 NaN                            NaN
# 1                                 NaN                            NaN
# 2                                 NaN                            NaN
# 3                                 NaN                            NaN
# 4                                 NaN                            NaN
# ..                                ...                            ...
# 98                                NaN                            NaN
# 99                                NaN                            NaN
# 100                               NaN                            NaN
# 101                               NaN                            NaN
# 102                               NaN                            NaN
#
#      PROPERTY: O content (wppm) PROPERTY: N content (wppm)  \
# 0                        7946.0                        NaN
# 1                        7946.0                        NaN
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                           NaN                        NaN
# ..                          ...                        ...
# 98                          NaN                        NaN
# 99                          NaN                        NaN
# 100                         NaN                        NaN
# 101                         NaN                        NaN
# 102                         NaN                        NaN
#
#      PROPERTY: C content (wppm)                     REFERENCE: doi  \
# 0                           NaN      10.1016/j.jallcom.2018.11.318
# 1                           NaN      10.1016/j.jallcom.2018.11.318
# 2                           NaN         10.1016/j.msea.2019.138140
# 3                           NaN  10.1016/j.matchemphys.2017.06.054
# 4                           NaN                10.1557/jmr.2019.18
# ..                          ...                                ...
# 98                          NaN                  10.3390/e21020122
# 99                          NaN                  10.3390/e21020122
# 100                         NaN                  10.3390/e21020122
# 101                         NaN      10.1080/00325899.2019.1576389
# 102                         NaN            10.3390/coatings9010016
#
#      REFERENCE: year
# 0               2018
# 1               2018
# 2               2019
# 3               2017
# 4               2019
# ..               ...
# 98              2019
# 99              2019
# 100             2019
# 101             2019
# 102             2019
#
# [103 rows x 20 columns]

# %% [markdown]
# Notice that not all of the cells have useful values; some have `NaN` as their value (which means Not a Number). These could be due to any of a number of potential issues; perhaps the original reference did not report that value, meaning that information exists but is missing.
#
# There are some helper functions to help deal with `NaN` values in filters: `gr.not_nan(df.column)` will return `True` when its input is not `NaN`, while `gr.is_nan(df.column)` will do the reverse.

# %% [markdown]
# ### __qX__ Filter the MPEA dataset to only those rows with a valid Yield Strength. Compare the original number of rows with the number of valid rows.

# %%
###
# TASK: Filter the data to find the non-NaN Yield Strength values
###

# -- NO NEED TO EDIT; USE FOR COMPARISON -----
print("Original shape: {}".format(df_mpea.shape))

# -- WRITE YOUR CODE BELOW -----
(
    df_mpea
    >> gr.tf_filter(gr.not_nan(DF["PROPERTY: YS (MPa)"]))
)
# Out:
# Original shape: (1653, 20)
#       IDENTIFIER: Reference ID                                      FORMULA  \
# 0                          146                        Cr1 Mo1 Nb1 Ta1 V1 W1
# 1                          146                        Cr1 Mo1 Nb1 Ta1 V1 W1
# 2                          181  Al0.667 Co0.833 Cr0.833 Fe0.833 Ni0.833 Ti1
# 3                           19                        Al1 Cr1 Fe1 Mo0.8 Ni1
# 4                          186                           Cr1 Fe1 Mo1 Nb1 V1
# ...                        ...                                          ...
# 1141                       132                          Hf1 Nb1 Ta1 Ti1 Zr1
# 1142                       132                          Hf1 Nb1 Ta1 Ti1 Zr1
# 1143                       132                          Hf1 Nb1 Ta1 Ti1 Zr1
# 1144                       133                         Al1 Nb1 Ti1 V1 Zr0.5
# 1145                       133                              Hf1 Nb1 Ti1 Zr1
#
#      PROPERTY: Microstructure PROPERTY: Processing method  \
# 0                         NaN                      POWDER
# 1                         NaN                      POWDER
# 2                         NaN                        CAST
# 3                     B2+Sec.                        CAST
# 4                         NaN                        CAST
# ...                       ...                         ...
# 1141                      BCC                       OTHER
# 1142                      BCC                       OTHER
# 1143                      BCC                       OTHER
# 1144                      NaN                         NaN
# 1145                      NaN                         NaN
#
#       PROPERTY: grain size ($\mu$m)  PROPERTY: ROM Density (g/cm$^3$)  \
# 0                              5.01                               NaN
# 1                             10.80                               NaN
# 2                             22.03                               NaN
# 3                               NaN                               7.0
# 4                               NaN                               NaN
# ...                             ...                               ...
# 1141                          24.40                               NaN
# 1142                          31.30                               NaN
# 1143                          38.40                               NaN
# 1144                            NaN                               NaN
# 1145                            NaN                               NaN
#
#       PROPERTY: Exp. Density (g/cm$^3$)  PROPERTY: HV PROPERTY: Type of test  \
# 0                                   NaN         991.3                      C
# 1                                   NaN         988.3                      C
# 2                                   NaN         856.9                      C
# 3                                   NaN         854.0                      C
# 4                                   NaN         826.0                      C
# ...                                 ...           ...                    ...
# 1141                                NaN           NaN                      T
# 1142                                NaN           NaN                      T
# 1143                                NaN           NaN                      T
# 1144                               5.64           NaN                      C
# 1145                                NaN           NaN                      C
#
#       PROPERTY: Test temperature ($^\circ$C)  PROPERTY: YS (MPa)  \
# 0                                       25.0              3410.0
# 1                                       25.0              3338.0
# 2                                       25.0              1272.0
# 3                                       25.0              1513.0
# 4                                       25.0              2663.0
# ...                                      ...                 ...
# 1141                                    25.0              1107.0
# 1142                                    25.0              1115.0
# 1143                                    25.0              1114.0
# 1144                                    25.0              1480.0
# 1145                                    25.0               879.0
#
#       PROPERTY: UTS (MPa)  PROPERTY: Elongation (%)  \
# 0                     NaN                      2.00
# 1                     NaN                      1.90
# 2                     NaN                      3.15
# 3                  1513.0                       NaN
# 4                     NaN                      2.70
# ...                   ...                       ...
# 1141                977.0                     13.90
# 1142                830.0                     18.50
# 1143                935.0                     12.20
# 1144                  NaN                     50.00
# 1145                  NaN                     16.50
#
#       PROPERTY: Elongation plastic (%)  PROPERTY: Young modulus (GPa)  \
# 0                                  NaN                            NaN
# 1                                  NaN                            NaN
# 2                                  NaN                            NaN
# 3                                  0.0                            NaN
# 4                                  NaN                            NaN
# ...                                ...                            ...
# 1141                               NaN                           92.6
# 1142                               NaN                           92.6
# 1143                               NaN                          101.3
# 1144                               NaN                            NaN
# 1145                               NaN                            NaN
#
#       PROPERTY: O content (wppm) PROPERTY: N content (wppm)  \
# 0                         7946.0                        NaN
# 1                         7946.0                        NaN
# 2                            NaN                        NaN
# 3                            NaN                        NaN
# 4                            NaN                        NaN
# ...                          ...                        ...
# 1141                         NaN                        NaN
# 1142                         NaN                        NaN
# 1143                         NaN                        NaN
# 1144                         NaN                        NaN
# 1145                         NaN                        NaN
#
#       PROPERTY: C content (wppm)                 REFERENCE: doi  \
# 0                            NaN  10.1016/j.jallcom.2018.11.318
# 1                            NaN  10.1016/j.jallcom.2018.11.318
# 2                            NaN  10.1016/j.jallcom.2019.07.100
# 3                            NaN  10.1016/j.jallcom.2013.03.253
# 4                            NaN     10.1007/s40195-019-00935-x
# ...                          ...                            ...
# 1141                         NaN      10.1007/s11661-018-4646-8
# 1142                         NaN      10.1007/s11661-018-4646-8
# 1143                         NaN      10.1007/s11661-018-4646-8
# 1144                         NaN  10.1080/02670836.2018.1446267
# 1145                         NaN  10.1080/02670836.2018.1446267
#
#       REFERENCE: year
# 0                2018
# 1                2018
# 2                2019
# 3                2013
# 4                2019
# ...               ...
# 1141             2019
# 1142             2019
# 1143             2019
# 1144             2018
# 1145             2018
#
# [1146 rows x 20 columns]

# %% [markdown]
# ### Mutating
#
# The `tf_mutate` verb allows us to create / modify columns based on existing column values. For instance, we could use a mutation to convert the units in a column:

# %%
## NOTE: No need to edit
(
    df_mpea
    >> gr.tf_mutate(
        E_MPa = DF["PROPERTY: Young modulus (GPa)"] * 1000
    )
)
# Out:
#       IDENTIFIER: Reference ID                                      FORMULA  \
# 0                          146                        Cr1 Mo1 Nb1 Ta1 V1 W1
# 1                          146                        Cr1 Mo1 Nb1 Ta1 V1 W1
# 2                          137                              Co1 Cr1 Fe1 Ni1
# 3                           19                          Al1 Cr1 Fe1 Mo1 Ni1
# 4                          155  Al1 Co0.426 Cr0.383 Cu0.106 Fe0.106 Ni0.106
# ...                        ...                                          ...
# 1648                       132                          Hf1 Nb1 Ta1 Ti1 Zr1
# 1649                       132                          Hf1 Nb1 Ta1 Ti1 Zr1
# 1650                       132                          Hf1 Nb1 Ta1 Ti1 Zr1
# 1651                       133                         Al1 Nb1 Ti1 V1 Zr0.5
# 1652                       133                              Hf1 Nb1 Ti1 Zr1
#
#      PROPERTY: Microstructure PROPERTY: Processing method  \
# 0                         NaN                      POWDER
# 1                         NaN                      POWDER
# 2                         FCC                        CAST
# 3                     B2+Sec.                        CAST
# 4                         NaN                         NaN
# ...                       ...                         ...
# 1648                      BCC                       OTHER
# 1649                      BCC                       OTHER
# 1650                      BCC                       OTHER
# 1651                      NaN                         NaN
# 1652                      NaN                         NaN
#
#       PROPERTY: grain size ($\mu$m)  PROPERTY: ROM Density (g/cm$^3$)  \
# 0                              5.01                               NaN
# 1                             10.80                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               7.2
# 4                               NaN                               NaN
# ...                             ...                               ...
# 1648                          50.10                               NaN
# 1649                          21.90                               NaN
# 1650                          75.50                               NaN
# 1651                            NaN                               NaN
# 1652                            NaN                               NaN
#
#       PROPERTY: Exp. Density (g/cm$^3$)  PROPERTY: HV PROPERTY: Type of test  \
# 0                                   NaN         991.3                      C
# 1                                   NaN         988.3                      C
# 2                                   NaN          94.7                    NaN
# 3                                   NaN         905.0                    NaN
# 4                                   NaN         883.0                    NaN
# ...                                 ...           ...                    ...
# 1648                                NaN           NaN                    NaN
# 1649                                NaN           NaN                    NaN
# 1650                                NaN           NaN                    NaN
# 1651                               5.64           NaN                      C
# 1652                                NaN           NaN                      C
#
#       PROPERTY: Test temperature ($^\circ$C)  ...  PROPERTY: UTS (MPa)  \
# 0                                       25.0  ...                  NaN
# 1                                       25.0  ...                  NaN
# 2                                        NaN  ...                  NaN
# 3                                       25.0  ...                  NaN
# 4                                        NaN  ...                  NaN
# ...                                      ...  ...                  ...
# 1648                                     NaN  ...                  NaN
# 1649                                     NaN  ...                  NaN
# 1650                                     NaN  ...                  NaN
# 1651                                    25.0  ...                  NaN
# 1652                                    25.0  ...                  NaN
#
#       PROPERTY: Elongation (%)  PROPERTY: Elongation plastic (%)  \
# 0                          2.0                               NaN
# 1                          1.9                               NaN
# 2                          NaN                               NaN
# 3                          NaN                               NaN
# 4                          NaN                               NaN
# ...                        ...                               ...
# 1648                       NaN                               NaN
# 1649                       NaN                               NaN
# 1650                       NaN                               NaN
# 1651                      50.0                               NaN
# 1652                      16.5                               NaN
#
#       PROPERTY: Young modulus (GPa)  PROPERTY: O content (wppm)  \
# 0                               NaN                      7946.0
# 1                               NaN                      7946.0
# 2                               NaN                         NaN
# 3                               NaN                         NaN
# 4                               NaN                         NaN
# ...                             ...                         ...
# 1648                            NaN                         NaN
# 1649                            NaN                         NaN
# 1650                            NaN                         NaN
# 1651                            NaN                         NaN
# 1652                            NaN                         NaN
#
#       PROPERTY: N content (wppm) PROPERTY: C content (wppm)  \
# 0                            NaN                        NaN
# 1                            NaN                        NaN
# 2                            NaN                        NaN
# 3                            NaN                        NaN
# 4                            NaN                        NaN
# ...                          ...                        ...
# 1648                         NaN                        NaN
# 1649                         NaN                        NaN
# 1650                         NaN                        NaN
# 1651                         NaN                        NaN
# 1652                         NaN                        NaN
#
#                      REFERENCE: doi REFERENCE: year  E_MPa
# 0     10.1016/j.jallcom.2018.11.318            2018    NaN
# 1     10.1016/j.jallcom.2018.11.318            2018    NaN
# 2      10.1016/j.matdes.2019.107698            2019    NaN
# 3     10.1016/j.jallcom.2013.03.253            2013    NaN
# 4     10.1016/j.actamat.2019.03.010            2019    NaN
# ...                             ...             ...    ...
# 1648      10.1007/s11661-018-4646-8            2019    NaN
# 1649      10.1007/s11661-018-4646-8            2019    NaN
# 1650      10.1007/s11661-018-4646-8            2019    NaN
# 1651  10.1080/02670836.2018.1446267            2018    NaN
# 1652  10.1080/02670836.2018.1446267            2018    NaN
#
# [1653 rows x 21 columns]

# %% [markdown]
# This might be useful if we aimed to compare two quantities; elasticity and ultimate tensile strength are somewhat related properties, so we might want to compare them.

# %%
## NOTE: No need to edit
(
    df_mpea
    >> gr.tf_mutate(
        E_MPa = DF["PROPERTY: Young modulus (GPa)"] * 1000
    )
    >> gr.tf_rename(
        UTS_MPa = "PROPERTY: UTS (MPa)"
    )
    >> gr.tf_filter(
        gr.not_nan(DF.UTS_MPa),
        gr.not_nan(DF.E_MPa),
    )
    >> gr.tf_select(
        "UTS_MPa",
        "E_MPa",
        gr.everything(),
    )
)
# Out:
#      UTS_MPa     E_MPa  IDENTIFIER: Reference ID  \
# 0     1030.0   94000.0                        66
# 1     2644.0  205000.0                        19
# 2     2368.0  123000.0                        39
# 3     3285.0  192000.0                         8
# 4     3222.0  197000.0                        19
# ..       ...       ...                       ...
# 162   1066.0  105300.0                       132
# 163    964.0   91600.0                       132
# 164    977.0   92600.0                       132
# 165    830.0   92600.0                       132
# 166    935.0  101300.0                       132
#
#                                FORMULA PROPERTY: Microstructure  \
# 0    Al1 Co0.5 Cr0.5 Fe0.5 Ni0.5 Ti0.5                      NaN
# 1                Al1 Cr1 Fe1 Mo0.5 Ni1                      NaN
# 2          Al1 Mo0.5 Nb1 Ta0.5 Ti1 Zr1                   BCC+B2
# 3            Al1 Co1 Cr1 Fe1 Nb0.1 Ni1                      BCC
# 4                Al1 Cr1 Fe1 Mo0.2 Ni1                      NaN
# ..                                 ...                      ...
# 162                Hf1 Nb1 Ta1 Ti1 Zr1                      BCC
# 163                Hf1 Nb1 Ta1 Ti1 Zr1                      BCC
# 164                Hf1 Nb1 Ta1 Ti1 Zr1                      BCC
# 165                Hf1 Nb1 Ta1 Ti1 Zr1                      BCC
# 166                Hf1 Nb1 Ta1 Ti1 Zr1                      BCC
#
#     PROPERTY: Processing method  PROPERTY: grain size ($\mu$m)  \
# 0                          CAST                            NaN
# 1                          CAST                            NaN
# 2                         OTHER                           75.0
# 3                          CAST                            NaN
# 4                          CAST                            NaN
# ..                          ...                            ...
# 162                       OTHER                            NaN
# 163                       OTHER                            NaN
# 164                       OTHER                           24.4
# 165                       OTHER                           31.3
# 166                       OTHER                           38.4
#
#      PROPERTY: ROM Density (g/cm$^3$)  PROPERTY: Exp. Density (g/cm$^3$)  \
# 0                                 5.6                                NaN
# 1                                 6.8                                NaN
# 2                                 7.1                                NaN
# 3                                 6.8                                NaN
# 4                                 6.5                                NaN
# ..                                ...                                ...
# 162                               NaN                                NaN
# 163                               NaN                                NaN
# 164                               NaN                                NaN
# 165                               NaN                                NaN
# 166                               NaN                                NaN
#
#      PROPERTY: HV  ... PROPERTY: Test temperature ($^\circ$C)  \
# 0           643.0  ...                                   25.0
# 1           622.0  ...                                   25.0
# 2           591.0  ...                                   25.0
# 3           569.0  ...                                   25.0
# 4           549.0  ...                                   25.0
# ..            ...  ...                                    ...
# 162           NaN  ...                                   25.0
# 163           NaN  ...                                   25.0
# 164           NaN  ...                                   25.0
# 165           NaN  ...                                   25.0
# 166           NaN  ...                                   25.0
#
#      PROPERTY: YS (MPa)  PROPERTY: Elongation (%)  \
# 0                   NaN                       NaN
# 1                1749.0                       NaN
# 2                2000.0                      10.0
# 3                1641.0                       NaN
# 4                1487.0                       NaN
# ..                  ...                       ...
# 162              1094.0                       6.0
# 163              1071.0                       4.6
# 164              1107.0                      13.9
# 165              1115.0                      18.5
# 166              1114.0                      12.2
#
#      PROPERTY: Elongation plastic (%)  PROPERTY: Young modulus (GPa)  \
# 0                                 5.0                           94.0
# 1                                13.0                          205.0
# 2                                 NaN                          123.0
# 3                                17.0                          192.0
# 4                                29.0                          197.0
# ..                                ...                            ...
# 162                               NaN                          105.3
# 163                               NaN                           91.6
# 164                               NaN                           92.6
# 165                               NaN                           92.6
# 166                               NaN                          101.3
#
#      PROPERTY: O content (wppm)  PROPERTY: N content (wppm)  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
# ..                          ...                         ...
# 162                         NaN                         NaN
# 163                         NaN                         NaN
# 164                         NaN                         NaN
# 165                         NaN                         NaN
# 166                         NaN                         NaN
#
#     PROPERTY: C content (wppm)                 REFERENCE: doi REFERENCE: year
# 0                          NaN     10.1016/j.msea.2008.12.053            2008
# 1                          NaN  10.1016/j.jallcom.2013.03.253            2013
# 2                          NaN      10.1007/s11837-014-1066-0            2014
# 3                          NaN     10.1016/j.msea.2011.10.110            2011
# 4                          NaN  10.1016/j.jallcom.2013.03.253            2013
# ..                         ...                            ...             ...
# 162                        NaN      10.1007/s11661-018-4646-8            2019
# 163                        NaN      10.1007/s11661-018-4646-8            2019
# 164                        NaN      10.1007/s11661-018-4646-8            2019
# 165                        NaN      10.1007/s11661-018-4646-8            2019
# 166                        NaN      10.1007/s11661-018-4646-8            2019
#
# [167 rows x 21 columns]

# %% [markdown]
# ### __QX__ Convert the weight parts per million (wppm) of Oxygen to a (weight) percent.

# %%
###
# TASK: Convert wppm to a weight percentage
# NOTE: There is some scaffolding code; you need only
#       write the call to tf_mutate
###

(
    df_mpea
    >> gr.tf_filter(
        gr.not_nan(DF["PROPERTY: O content (wppm)"]),
    )
# -- WRITE YOUR CODE HERE -----

    >> gr.tf_mutate(
        O_percent=DF["PROPERTY: O content (wppm)"] * 100 / 1e6
    )
    >> gr.tf_select("O_percent", gr.everything())
    >> gr.tf_head()
)
# Out:
#    O_percent  IDENTIFIER: Reference ID                FORMULA  \
# 0     0.7946                       146  Cr1 Mo1 Nb1 Ta1 V1 W1
# 1     0.7946                       146  Cr1 Mo1 Nb1 Ta1 V1 W1
# 2     0.4800                       127         Nb1 Ta1 Ti1 V1
# 3     0.7946                       146  Cr1 Mo1 Nb1 Ta1 V1 W1
# 4     0.7946                       146  Cr1 Mo1 Nb1 Ta1 V1 W1
#
#   PROPERTY: Microstructure PROPERTY: Processing method  \
# 0                      NaN                      POWDER
# 1                      NaN                      POWDER
# 2                      BCC                      POWDER
# 3                      NaN                      POWDER
# 4                      NaN                      POWDER
#
#    PROPERTY: grain size ($\mu$m)  PROPERTY: ROM Density (g/cm$^3$)  \
# 0                           5.01                               NaN
# 1                          10.80                               NaN
# 2                          38.00                               NaN
# 3                           0.54                               NaN
# 4                           1.24                               NaN
#
#    PROPERTY: Exp. Density (g/cm$^3$)  PROPERTY: HV PROPERTY: Type of test  \
# 0                                NaN         991.3                      C
# 1                                NaN         988.3                      C
# 2                                NaN         510.9                      C
# 3                                NaN        1072.0                      C
# 4                                NaN        1010.0                      C
#
#    ...  PROPERTY: YS (MPa)  PROPERTY: UTS (MPa)  PROPERTY: Elongation (%)  \
# 0  ...              3410.0                  NaN                       2.0
# 1  ...              3338.0                  NaN                       1.9
# 2  ...              1373.0                  NaN                      29.5
# 3  ...                 NaN                  NaN                       NaN
# 4  ...              3416.0                  NaN                       5.3
#
#    PROPERTY: Elongation plastic (%)  PROPERTY: Young modulus (GPa)  \
# 0                               NaN                            NaN
# 1                               NaN                            NaN
# 2                               NaN                            NaN
# 3                               NaN                            NaN
# 4                               NaN                            NaN
#
#    PROPERTY: O content (wppm)  PROPERTY: N content (wppm)  \
# 0                      7946.0                         NaN
# 1                      7946.0                         NaN
# 2                      4800.0                         NaN
# 3                      7946.0                         NaN
# 4                      7946.0                         NaN
#
#   PROPERTY: C content (wppm)                 REFERENCE: doi REFERENCE: year
# 0                        NaN  10.1016/j.jallcom.2018.11.318            2018
# 1                        NaN  10.1016/j.jallcom.2018.11.318            2018
# 2                     1900.0  10.1016/j.jallcom.2018.10.230            2018
# 3                        NaN  10.1016/j.jallcom.2018.11.318            2018
# 4                        NaN  10.1016/j.jallcom.2018.11.318            2018
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Converting Data
#
# (TODO there's something wrong with the Nitrogen content column)

# %%
(
    df_mpea
    >> gr.tf_select(gr.contains("content"))
).dtypes
# Out:
# PROPERTY: O content (wppm)    float64
# PROPERTY: N content (wppm)     object
# PROPERTY: C content (wppm)    float64
# dtype: object

# %% [markdown]
# The Oxygen and Carbon content columns are fine---they're `float64`, which is a numeric type as we'd expect. But the Nitrogen content is an `object`. Let's see what specific values this column takes:

# %%
set(
    df_mpea["PROPERTY: N content (wppm)"]
)
# Out:
# {'5', nan, 'undetectable'}

# %% [markdown]
# It seems that the original data is mixed; some values are a numeric ppm value, while others are the qualitative statement `"undetectable"` (and yet others are simply missing). We can use the Grama helper `gr.as_numeric()` to help convert the data to a numeric type.

# %%
(
    df_mpea
    >> gr.tf_rename(N_wppm="PROPERTY: N content (wppm)")
    >> gr.tf_mutate(N_converted = gr.as_numeric(DF.N_wppm))
    >> gr.tf_select("N_wppm", "N_converted")
).dtypes
# Out:
# N_wppm          object
# N_converted    float64
# dtype: object

# %%
(
    df_mpea
    >> gr.tf_rename(N_wppm="PROPERTY: N content (wppm)")
    >> gr.tf_mutate(N_converted = gr.as_numeric(DF.N_wppm))
    >> gr.tf_select("N_wppm", "N_converted")
)

# %% [markdown]
# ## Pivoting Data
#
# ---
#
# TODO

# %%
from grama.data import df_stang_wide
df_stang_wide

# %% [markdown]
# Our goal will be to wrangle this messy, wide dataset into tidy, long format.

# %%
from grama.data import df_stang
df_stang

# %% [markdown]
# (What does pivoting look like? Here's an example.)

# %%
df_tmp = (
    gr.df_make(
        A=[1, 2, 3],
        B=[4, 5, 6],
        C=[7, 8, 9],
    )
)
print(df_tmp)

(
    df_tmp
    >> gr.tf_pivot_longer(
        columns=["A", "B", "C"],
        names_to="name",
        values_to="value",
    )
)

# %% [markdown]
# ### __QX__
#
# (Make sure to add an `observation` column with the `index_to` argument.)

# %%
df_qX = (
    df_stang_wide
    >> gr.tf_pivot_longer(
        columns=["E_00", "mu_00", "E_45", "mu_45", "E_90", "mu_90"],
        names_to="name",
        values_to="value",
        index_to="observation",
    )
)
df_qX

# %% [markdown]
# Execute the following to check your work.

# %%
try:
    assert(df_qX.shape[0] == 54)
except AssertionError:
    raise AssertionError("The DataFrame is not sufficiently long; did you pivot?")
    
try:
    assert(df_qX.shape[1] == 5)
except AssertionError:
    raise AssertionError("The DataFrame should have five columns")
    
try:
    assert("observation" in df_qX.columns)
except AssertionError:
    raise AssertionError("The DataFrame should have five columns")
    
print("Success!")

# %% [markdown]
# ### __QY__

# %%
df_qY = (
    df_qX
    >> gr.tf_separate(
        column="name",
        into=["var", "angle"],
        sep="_",
    )
)
df_qY

# %%
try:
    assert(df_qY.shape[0] == 54)
except AssertionError:
    raise AssertionError("The DataFrame is not the right length; how did that happen?")
    
try:
    assert(df_qY.shape[1] == 6)
except AssertionError:
    raise AssertionError("The DataFrame should have six columns")
    
try:
    assert("angle" in df_qY.columns)
except AssertionError:
    raise AssertionError("The DataFrame should have an 'angle' column")
    
print("Success!")

# %% [markdown]
# ### __QZ__
#
# *Hint*: You should only need to set the `names_from` and `values_from` arguments with this function.

# %%
df_qZ = (
    df_qY
    >> gr.tf_pivot_wider(
        names_from="var",
        values_from="value",
    )
)
df_qZ

# %%
try:
    assert(df_qZ.shape[0] == 27)
except AssertionError:
    raise AssertionError("The DataFrame is not the right length; how did that happen?")
    
try:
    assert("angle" in df_qZ.columns)
except AssertionError:
    raise AssertionError("The DataFrame should have an 'angle' column")
    
try:
    assert("E" in df_qZ.columns)
except AssertionError:
    raise AssertionError("The DataFrame should have an 'E' column")
    
try:
    assert("mu" in df_qZ.columns)
except AssertionError:
    raise AssertionError("The DataFrame should have an 'mu' column")
    
print("Success!")

# %% [markdown]
# ### Bonus: One-step pivot

# %%
(
    df_stang_wide
    >> gr.tf_pivot_longer(
        columns=["E_00", "mu_00", "E_45", "mu_45", "E_90", "mu_90"],
        names_to=[".value", "angle"],
        names_sep="_",
        values_to="value",
    )
)

# %% [markdown]
# ## Wrangling Data
# [Hadley Wickham](http://hadley.nz/) -- author of the `tidyverse` and data science superstar -- notes that "wrangling data is 80% boredom and 20% screaming". To give you a sense of why this stuff is hard (but hopefully avoid the screaming), I'm leaving one of the wrangling steps in the workflow here:

# %% [markdown]
# It's not obvious from the exercises above, but *there's an issue with these data*.

# %%
df_data.dtypes

# %% [markdown]
# All of the entries are objects, not numbers! We'll need to convert these to numeric values. The following slightly-mysterious call will cast every column of `df_data` to a numeric type and modify the DataFrame.

# %%
df_data = df_data.apply(pd.to_numeric)

# %% [markdown]
# Let's check the data types again:

# %%
df_data.dtypes

# %% [markdown]
# These are numbers we can work with!

# %% [markdown]
# ## Basic DataFrame Operations

# %% [markdown]
# With the numerical issues above sorted out, we can carry out *quantitative* operations on the dataframe. One useful thing we can do is compute a set of *summaries* on the data using `describe()`.

# %%
df_data.describe()

# %% [markdown]
# These summaries include things like the `mean` and standard deviation (`std`), as well as quartiles of the data. These give us a sense of *typical* values; for instance, we can see that a large fraction of observations have a zero-"Diffusion time", but at least one observation has a value `> 70`.

# %% [markdown]
# ### Special indexing
# One of the most powerful features of pandas is the ability to do *logical indexing*; we may provide an array of `True` or `False` values to select only those rows with `True` values. For instance, we could do the following to select the third row.

# %%
idx_boolean = [False] * df_data.shape[0]  # Mostly-false array
idx_boolean[2] = True  # Make the third entry True
df_data[idx_boolean]

# %% [markdown]
# Where this kind of *logical indexing* becomes helpful is when we chain this with the conditionals we learned in the previous exercise. For instance, we could use logic *using one of the columns* to effectively "filter" for variables that meet some condition. For instance, the following will filter for nonzero "Carburization Time".

# %%
df_data[df_data["Carburization Time"] > 0].head()

# %% [markdown]
# ### Q5: Basic data operations
# Once more, use the [pandas documentation](https://pandas.pydata.org/pandas-docs/stable/getting_started/10min.html) to learn how to do the following tasks:
#
# - Select only those rows for which "Diffusion time" is greater than 70
# - Sort df_data in descending order by "Fatigue Strength" and return the top 10
# - Take the average of "Normalizing Temperature" and "Tempering Temperature" and add the column "avg_temp" (You may need to Google how to do this one!)

# %%
###
# TASK: Basic data operations
# TODO: Select rows for which "Diffusion time" > 70
###

# -- WRITE YOUR CODE BELOW -----
df_data[df_data["Diffusion time"] > 70]

# %%
###
# TASK: Basic data operations
# TODO: Sort by "Fatigue Strength" in descending order, take the top-10
###

# -- WRITE YOUR CODE BELOW -----
df_data.sort_values(by="Fatigue Strength", ascending=False).head(10)

# %%
###
# TASK: Basic data operations
# TODO: Average "Normalizing Temperature" and "Tempering Temperature" into the column "avg_tmp", return the head
###

# -- WRITE YOUR CODE BELOW -----
df_data.assign(
    avg_tmp=0.5 * (df_data["Normalizing Temperature"] + df_data["Tempering Temperature"])).head()

# %% [markdown]
# ## Endnotes
#
# - The data portions of Grama make heavy use of ideas from the [Tidyverse](https://www.tidyverse.org/); specifically the [dplyr](https://dplyr.tidyverse.org/) package. However, those packages are for the R programming language.
