# %% [markdown]
# ## Programmatic Data Operations
#
# *Authors: Zach del Rosario*

# %% [markdown]
# The purpose of this exercise is to give you some tools to work with data *programmatically*; that is, using a programming language. While you can carry out many data operations by hand or with spreadsheet programs, you will see that doing things programmatically is extremely powerful.
#
# ### Learning Outcomes
# By working through this notebook, you will be able to:
#
# - Learn some basics of *data wrangling*
# - Use DataFrame operations from the package `py-grama`

# %%
import numpy as np
import pandas as pd
import grama as gr

DF = gr.Intention()

# For downloading data
import os
import requests

# %% [markdown]
# ## DataFrames
#
# ---

# %% [markdown]
# A `DataFrame` is a data structure provided by Pandas. In contrast with `lists` (which we saw in the previous exercise), DataFrames are explicitly designed to facilitate data analysis. Accordingly, they provide a number of helpful features that aid in data analysis and operations.
#
# A `DataFrame` is a *rectangular* representation of data -- it consists of rows and columns. Each *row* represents an *observation* -- a single instance of data. Each *column* represents a *variable* -- a particular attribute of the observation.

# %% [markdown]
# For instance, the following code chunk downloads a alloy dataset into the DataFrame `df_mpea` -- here each row is an alloy, and each column is some physical property of that alloy.

# %%
# Filename for local data
filename_data = "./data/mpea.csv"

# The following code downloads the data, or (after downloaded)
# loads the data from a cached CSV on your machine
if not os.path.exists(filename_data):
    # Make request for data
    url_data = "https://docs.google.com/spreadsheets/u/1/d/1MsF4_jhWtEuZSvWfXLDHWEqLMScGCVXYWtqHW9Y7Yt0/export?format=csv"
    r = requests.get(url_data, allow_redirects=True)
    open(filename_data, 'wb').write(r.content)
    print("   MPEA data downloaded from public Google sheet")
else:
    # Note data already exists
    print("    MPEA data loaded locally")
    
# Read the data into memory
df_mpea = pd.read_csv(filename_data)

# Check basic facts
print(df_mpea.shape)
df_mpea.head()
# Out:
#     MPEA data loaded locally
# (1653, 20)
#    IDENTIFIER: Reference ID                                      FORMULA  \
# 0                       146                        Cr1 Mo1 Nb1 Ta1 V1 W1
# 1                       146                        Cr1 Mo1 Nb1 Ta1 V1 W1
# 2                       137                              Co1 Cr1 Fe1 Ni1
# 3                        19                          Al1 Cr1 Fe1 Mo1 Ni1
# 4                       155  Al1 Co0.426 Cr0.383 Cu0.106 Fe0.106 Ni0.106
#
#   PROPERTY: Microstructure PROPERTY: Processing method  \
# 0                      NaN                      POWDER
# 1                      NaN                      POWDER
# 2                      FCC                        CAST
# 3                  B2+Sec.                        CAST
# 4                      NaN                         NaN
#
#    PROPERTY: grain size ($\mu$m)  PROPERTY: ROM Density (g/cm$^3$)  \
# 0                           5.01                               NaN
# 1                          10.80                               NaN
# 2                            NaN                               NaN
# 3                            NaN                               7.2
# 4                            NaN                               NaN
#
#    PROPERTY: Exp. Density (g/cm$^3$)  PROPERTY: HV PROPERTY: Type of test  \
# 0                                NaN         991.3                      C
# 1                                NaN         988.3                      C
# 2                                NaN          94.7                    NaN
# 3                                NaN         905.0                    NaN
# 4                                NaN         883.0                    NaN
#
#    PROPERTY: Test temperature ($^\circ$C)  PROPERTY: YS (MPa)  \
# 0                                    25.0              3410.0
# 1                                    25.0              3338.0
# 2                                     NaN                 NaN
# 3                                    25.0                 NaN
# 4                                     NaN                 NaN
#
#    PROPERTY: UTS (MPa)  PROPERTY: Elongation (%)  \
# 0                  NaN                       2.0
# 1                  NaN                       1.9
# 2                  NaN                       NaN
# 3                  NaN                       NaN
# 4                  NaN                       NaN
#
#    PROPERTY: Elongation plastic (%)  PROPERTY: Young modulus (GPa)  \
# 0                               NaN                            NaN
# 1                               NaN                            NaN
# 2                               NaN                            NaN
# 3                               NaN                            NaN
# 4                               NaN                            NaN
#
#    PROPERTY: O content (wppm) PROPERTY: N content (wppm)  \
# 0                      7946.0                        NaN
# 1                      7946.0                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
#
#    PROPERTY: C content (wppm)                 REFERENCE: doi  REFERENCE: year
# 0                         NaN  10.1016/j.jallcom.2018.11.318             2018
# 1                         NaN  10.1016/j.jallcom.2018.11.318             2018
# 2                         NaN   10.1016/j.matdes.2019.107698             2019
# 3                         NaN  10.1016/j.jallcom.2013.03.253             2013
# 4                         NaN  10.1016/j.actamat.2019.03.010             2019

# %% [markdown]
# ### __Q1__: Inspecting a DataFrame
# Consult the [pandas documentation](https://pandas.pydata.org/pandas-docs/stable/getting_started/10min.html) (it might be useful to use a page search) and use some basic calls on `df_data` to answer the following questions:
#
# - What are the *last* five observations in the DataFrame?
# - How many rows are in `df_data`? How many columns?
# - How would we access the column `PROPERTY: Microstructure`?

# %%
###
# TASK: Inspect df_data
# TODO: Show the last five observations of df_mpea
###

# -- WRITE YOUR CODE BELOW -----
# solution-begin
df_mpea.tail(5)
# solution-end
# Out:
#       IDENTIFIER: Reference ID               FORMULA PROPERTY: Microstructure  \
# 1648                       132   Hf1 Nb1 Ta1 Ti1 Zr1                      BCC
# 1649                       132   Hf1 Nb1 Ta1 Ti1 Zr1                      BCC
# 1650                       132   Hf1 Nb1 Ta1 Ti1 Zr1                      BCC
# 1651                       133  Al1 Nb1 Ti1 V1 Zr0.5                      NaN
# 1652                       133       Hf1 Nb1 Ti1 Zr1                      NaN
#
#      PROPERTY: Processing method  PROPERTY: grain size ($\mu$m)  \
# 1648                       OTHER                           50.1
# 1649                       OTHER                           21.9
# 1650                       OTHER                           75.5
# 1651                         NaN                            NaN
# 1652                         NaN                            NaN
#
#       PROPERTY: ROM Density (g/cm$^3$)  PROPERTY: Exp. Density (g/cm$^3$)  \
# 1648                               NaN                                NaN
# 1649                               NaN                                NaN
# 1650                               NaN                                NaN
# 1651                               NaN                               5.64
# 1652                               NaN                                NaN
#
#       PROPERTY: HV PROPERTY: Type of test  \
# 1648           NaN                    NaN
# 1649           NaN                    NaN
# 1650           NaN                    NaN
# 1651           NaN                      C
# 1652           NaN                      C
#
#       PROPERTY: Test temperature ($^\circ$C)  PROPERTY: YS (MPa)  \
# 1648                                     NaN                 NaN
# 1649                                     NaN                 NaN
# 1650                                     NaN                 NaN
# 1651                                    25.0              1480.0
# 1652                                    25.0               879.0
#
#       PROPERTY: UTS (MPa)  PROPERTY: Elongation (%)  \
# 1648                  NaN                       NaN
# 1649                  NaN                       NaN
# 1650                  NaN                       NaN
# 1651                  NaN                      50.0
# 1652                  NaN                      16.5
#
#       PROPERTY: Elongation plastic (%)  PROPERTY: Young modulus (GPa)  \
# 1648                               NaN                            NaN
# 1649                               NaN                            NaN
# 1650                               NaN                            NaN
# 1651                               NaN                            NaN
# 1652                               NaN                            NaN
#
#       PROPERTY: O content (wppm) PROPERTY: N content (wppm)  \
# 1648                         NaN                        NaN
# 1649                         NaN                        NaN
# 1650                         NaN                        NaN
# 1651                         NaN                        NaN
# 1652                         NaN                        NaN
#
#       PROPERTY: C content (wppm)                 REFERENCE: doi  \
# 1648                         NaN      10.1007/s11661-018-4646-8
# 1649                         NaN      10.1007/s11661-018-4646-8
# 1650                         NaN      10.1007/s11661-018-4646-8
# 1651                         NaN  10.1080/02670836.2018.1446267
# 1652                         NaN  10.1080/02670836.2018.1446267
#
#       REFERENCE: year
# 1648             2019
# 1649             2019
# 1650             2019
# 1651             2018
# 1652             2018

# %%
###
# TASK: Inspect df_mpea
# TODO: Determine the number of rows and columns in df_mpea
###

# -- WRITE YOUR CODE BELOW -----
# solution-begin
df_mpea.shape  # rows, columns
# solution-end
# Out:
# (1653, 20)

# %%
###
# TASK: Inspect df_data
# TODO: Grab the column `PROPERTY: Microstructure` alone
###

# -- WRITE YOUR CODE BELOW -----
# solution-begin
# Note that this returns a Pandas Series
df_mpea["PROPERTY: Microstructure"]
# And this returns a Pandas DataFrame
df_mpea[["PROPERTY: Microstructure"]]
# solution-end
# Out:
#      PROPERTY: Microstructure
# 0                         NaN
# 1                         NaN
# 2                         FCC
# 3                     B2+Sec.
# 4                         NaN
# ...                       ...
# 1648                      BCC
# 1649                      BCC
# 1650                      BCC
# 1651                      NaN
# 1652                      NaN
#
# [1653 rows x 1 columns]

# %% [markdown]
# These manipulations are simple, but they are bread-and-butter for studying new datasets.

# %% [markdown]
# ## Grama
#
# ---
#
# TODO the `py-grama` package builds on top of Pandas to provide a pipeline-based data (and model) infrastructure.
#
# Grama provides

# %%
(
   df_mpea
   >> gr.tf_head()
)
# Out:
#    IDENTIFIER: Reference ID                                      FORMULA  \
# 0                       146                        Cr1 Mo1 Nb1 Ta1 V1 W1
# 1                       146                        Cr1 Mo1 Nb1 Ta1 V1 W1
# 2                       137                              Co1 Cr1 Fe1 Ni1
# 3                        19                          Al1 Cr1 Fe1 Mo1 Ni1
# 4                       155  Al1 Co0.426 Cr0.383 Cu0.106 Fe0.106 Ni0.106
#
#   PROPERTY: Microstructure PROPERTY: Processing method  \
# 0                      NaN                      POWDER
# 1                      NaN                      POWDER
# 2                      FCC                        CAST
# 3                  B2+Sec.                        CAST
# 4                      NaN                         NaN
#
#    PROPERTY: grain size ($\mu$m)  PROPERTY: ROM Density (g/cm$^3$)  \
# 0                           5.01                               NaN
# 1                          10.80                               NaN
# 2                            NaN                               NaN
# 3                            NaN                               7.2
# 4                            NaN                               NaN
#
#    PROPERTY: Exp. Density (g/cm$^3$)  PROPERTY: HV PROPERTY: Type of test  \
# 0                                NaN         991.3                      C
# 1                                NaN         988.3                      C
# 2                                NaN          94.7                    NaN
# 3                                NaN         905.0                    NaN
# 4                                NaN         883.0                    NaN
#
#    PROPERTY: Test temperature ($^\circ$C)  PROPERTY: YS (MPa)  \
# 0                                    25.0              3410.0
# 1                                    25.0              3338.0
# 2                                     NaN                 NaN
# 3                                    25.0                 NaN
# 4                                     NaN                 NaN
#
#    PROPERTY: UTS (MPa)  PROPERTY: Elongation (%)  \
# 0                  NaN                       2.0
# 1                  NaN                       1.9
# 2                  NaN                       NaN
# 3                  NaN                       NaN
# 4                  NaN                       NaN
#
#    PROPERTY: Elongation plastic (%)  PROPERTY: Young modulus (GPa)  \
# 0                               NaN                            NaN
# 1                               NaN                            NaN
# 2                               NaN                            NaN
# 3                               NaN                            NaN
# 4                               NaN                            NaN
#
#    PROPERTY: O content (wppm) PROPERTY: N content (wppm)  \
# 0                      7946.0                        NaN
# 1                      7946.0                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
#
#    PROPERTY: C content (wppm)                 REFERENCE: doi  REFERENCE: year
# 0                         NaN  10.1016/j.jallcom.2018.11.318             2018
# 1                         NaN  10.1016/j.jallcom.2018.11.318             2018
# 2                         NaN   10.1016/j.matdes.2019.107698             2019
# 3                         NaN  10.1016/j.jallcom.2013.03.253             2013
# 4                         NaN  10.1016/j.actamat.2019.03.010             2019

# %% [markdown]
# It's helpful to think of the `>>` symbol as meaning "and then". That means code like this:
#
# ```
# (
#     df_mpea
#     >> gr.tf_filter( ... )
#     >> gr.tf_mutate( ... )
#     >> gr.tf_pivot_longer( ... )
# )
# ```
#
# Can be read something like an English sentence, where we are using various *verbs* to operate on the data:
#
# ```
# (
#     Start with df_mpea
#     and then filter the data
#     and then mutate the data
#     and then pivot the data in to a longer format
# )
# ```
#
# We don't yet know what these verbs do; we'll learn more in the exercises below!

# %% [markdown]
# ### Selecting
#
# TODO

# %%
(
    df_mpea
    >> gr.tf_select("FORMULA")
)
# Out:
#                                           FORMULA
# 0                           Cr1 Mo1 Nb1 Ta1 V1 W1
# 1                           Cr1 Mo1 Nb1 Ta1 V1 W1
# 2                                 Co1 Cr1 Fe1 Ni1
# 3                             Al1 Cr1 Fe1 Mo1 Ni1
# 4     Al1 Co0.426 Cr0.383 Cu0.106 Fe0.106 Ni0.106
# ...                                           ...
# 1648                          Hf1 Nb1 Ta1 Ti1 Zr1
# 1649                          Hf1 Nb1 Ta1 Ti1 Zr1
# 1650                          Hf1 Nb1 Ta1 Ti1 Zr1
# 1651                         Al1 Nb1 Ti1 V1 Zr0.5
# 1652                              Hf1 Nb1 Ti1 Zr1
#
# [1653 rows x 1 columns]

# %% [markdown]
# ### __qX__

# %%
(
    df_mpea
    >> gr.tf_select("FORMULA", "PROPERTY: Microstructure")
)
# Out:
#                                           FORMULA PROPERTY: Microstructure
# 0                           Cr1 Mo1 Nb1 Ta1 V1 W1                      NaN
# 1                           Cr1 Mo1 Nb1 Ta1 V1 W1                      NaN
# 2                                 Co1 Cr1 Fe1 Ni1                      FCC
# 3                             Al1 Cr1 Fe1 Mo1 Ni1                  B2+Sec.
# 4     Al1 Co0.426 Cr0.383 Cu0.106 Fe0.106 Ni0.106                      NaN
# ...                                           ...                      ...
# 1648                          Hf1 Nb1 Ta1 Ti1 Zr1                      BCC
# 1649                          Hf1 Nb1 Ta1 Ti1 Zr1                      BCC
# 1650                          Hf1 Nb1 Ta1 Ti1 Zr1                      BCC
# 1651                         Al1 Nb1 Ti1 V1 Zr0.5                      NaN
# 1652                              Hf1 Nb1 Ti1 Zr1                      NaN
#
# [1653 rows x 2 columns]

# %% [markdown]
# ### __qX__

# %%
(
    df_mpea
    >> gr.tf_select(gr.contains("REFERENCE"))
)
# Out:
#                      REFERENCE: doi  REFERENCE: year
# 0     10.1016/j.jallcom.2018.11.318             2018
# 1     10.1016/j.jallcom.2018.11.318             2018
# 2      10.1016/j.matdes.2019.107698             2019
# 3     10.1016/j.jallcom.2013.03.253             2013
# 4     10.1016/j.actamat.2019.03.010             2019
# ...                             ...              ...
# 1648      10.1007/s11661-018-4646-8             2019
# 1649      10.1007/s11661-018-4646-8             2019
# 1650      10.1007/s11661-018-4646-8             2019
# 1651  10.1080/02670836.2018.1446267             2018
# 1652  10.1080/02670836.2018.1446267             2018
#
# [1653 rows x 2 columns]

# %% [markdown]
# ### Renaming

# %%
(
    df_mpea
    >> gr.tf_rename(
        microstructure="PROPERTY: Microstructure",
    )
)
# Out:
#       IDENTIFIER: Reference ID                                      FORMULA  \
# 0                          146                        Cr1 Mo1 Nb1 Ta1 V1 W1
# 1                          146                        Cr1 Mo1 Nb1 Ta1 V1 W1
# 2                          137                              Co1 Cr1 Fe1 Ni1
# 3                           19                          Al1 Cr1 Fe1 Mo1 Ni1
# 4                          155  Al1 Co0.426 Cr0.383 Cu0.106 Fe0.106 Ni0.106
# ...                        ...                                          ...
# 1648                       132                          Hf1 Nb1 Ta1 Ti1 Zr1
# 1649                       132                          Hf1 Nb1 Ta1 Ti1 Zr1
# 1650                       132                          Hf1 Nb1 Ta1 Ti1 Zr1
# 1651                       133                         Al1 Nb1 Ti1 V1 Zr0.5
# 1652                       133                              Hf1 Nb1 Ti1 Zr1
#
#      microstructure PROPERTY: Processing method  \
# 0               NaN                      POWDER
# 1               NaN                      POWDER
# 2               FCC                        CAST
# 3           B2+Sec.                        CAST
# 4               NaN                         NaN
# ...             ...                         ...
# 1648            BCC                       OTHER
# 1649            BCC                       OTHER
# 1650            BCC                       OTHER
# 1651            NaN                         NaN
# 1652            NaN                         NaN
#
#       PROPERTY: grain size ($\mu$m)  PROPERTY: ROM Density (g/cm$^3$)  \
# 0                              5.01                               NaN
# 1                             10.80                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               7.2
# 4                               NaN                               NaN
# ...                             ...                               ...
# 1648                          50.10                               NaN
# 1649                          21.90                               NaN
# 1650                          75.50                               NaN
# 1651                            NaN                               NaN
# 1652                            NaN                               NaN
#
#       PROPERTY: Exp. Density (g/cm$^3$)  PROPERTY: HV PROPERTY: Type of test  \
# 0                                   NaN         991.3                      C
# 1                                   NaN         988.3                      C
# 2                                   NaN          94.7                    NaN
# 3                                   NaN         905.0                    NaN
# 4                                   NaN         883.0                    NaN
# ...                                 ...           ...                    ...
# 1648                                NaN           NaN                    NaN
# 1649                                NaN           NaN                    NaN
# 1650                                NaN           NaN                    NaN
# 1651                               5.64           NaN                      C
# 1652                                NaN           NaN                      C
#
#       PROPERTY: Test temperature ($^\circ$C)  PROPERTY: YS (MPa)  \
# 0                                       25.0              3410.0
# 1                                       25.0              3338.0
# 2                                        NaN                 NaN
# 3                                       25.0                 NaN
# 4                                        NaN                 NaN
# ...                                      ...                 ...
# 1648                                     NaN                 NaN
# 1649                                     NaN                 NaN
# 1650                                     NaN                 NaN
# 1651                                    25.0              1480.0
# 1652                                    25.0               879.0
#
#       PROPERTY: UTS (MPa)  PROPERTY: Elongation (%)  \
# 0                     NaN                       2.0
# 1                     NaN                       1.9
# 2                     NaN                       NaN
# 3                     NaN                       NaN
# 4                     NaN                       NaN
# ...                   ...                       ...
# 1648                  NaN                       NaN
# 1649                  NaN                       NaN
# 1650                  NaN                       NaN
# 1651                  NaN                      50.0
# 1652                  NaN                      16.5
#
#       PROPERTY: Elongation plastic (%)  PROPERTY: Young modulus (GPa)  \
# 0                                  NaN                            NaN
# 1                                  NaN                            NaN
# 2                                  NaN                            NaN
# 3                                  NaN                            NaN
# 4                                  NaN                            NaN
# ...                                ...                            ...
# 1648                               NaN                            NaN
# 1649                               NaN                            NaN
# 1650                               NaN                            NaN
# 1651                               NaN                            NaN
# 1652                               NaN                            NaN
#
#       PROPERTY: O content (wppm) PROPERTY: N content (wppm)  \
# 0                         7946.0                        NaN
# 1                         7946.0                        NaN
# 2                            NaN                        NaN
# 3                            NaN                        NaN
# 4                            NaN                        NaN
# ...                          ...                        ...
# 1648                         NaN                        NaN
# 1649                         NaN                        NaN
# 1650                         NaN                        NaN
# 1651                         NaN                        NaN
# 1652                         NaN                        NaN
#
#       PROPERTY: C content (wppm)                 REFERENCE: doi  \
# 0                            NaN  10.1016/j.jallcom.2018.11.318
# 1                            NaN  10.1016/j.jallcom.2018.11.318
# 2                            NaN   10.1016/j.matdes.2019.107698
# 3                            NaN  10.1016/j.jallcom.2013.03.253
# 4                            NaN  10.1016/j.actamat.2019.03.010
# ...                          ...                            ...
# 1648                         NaN      10.1007/s11661-018-4646-8
# 1649                         NaN      10.1007/s11661-018-4646-8
# 1650                         NaN      10.1007/s11661-018-4646-8
# 1651                         NaN  10.1080/02670836.2018.1446267
# 1652                         NaN  10.1080/02670836.2018.1446267
#
#       REFERENCE: year
# 0                2018
# 1                2018
# 2                2019
# 3                2013
# 4                2019
# ...               ...
# 1648             2019
# 1649             2019
# 1650             2019
# 1651             2018
# 1652             2018
#
# [1653 rows x 20 columns]

# %% [markdown]
# ## Interlude: Pipelines and the "Data Pronoun
#
# ---

# %% [markdown]
# (Illustrate the use of the data pronoun)
#
# Imagine we wanted to search through the dataset to find only those materials with a FCC microstructure. Above, we gave the `microstructure` column a new, convenient name. We might like to use that new, convenient name when searching for FCC materials. However, we're going to run into an issue:

# %%
## NOTE: Try uncommenting and running the following code; it WILL break!
# (
#     df_mpea
#     >> gr.tf_rename(
#         microstructure="PROPERTY: Microstructure",
#     )
#     >> gr.tf_filter(
#         df_mpea["microstructure"] == "FCC"
#     )
# )
# Out:
#      IDENTIFIER: Reference ID                        FORMULA microstructure  \
# 0                         137                Co1 Cr1 Fe1 Ni1            FCC
# 1                         209        Al0.5 Co1 Fe1 Ni1 Ti0.5            FCC
# 2                         120            Co1 Cr1 Cu1 Ni1 Zn1            FCC
# 3                          35                Al1 Cu1 Ni1 Ti1            FCC
# 4                         130  C0.429 Co1 Cr1 Fe1 Ni1 W0.429            FCC
# ..                        ...                            ...            ...
# 272                       119            Co1 Cr1 Cu1 Fe1 Ni1            FCC
# 273                       120            Co1 Cr1 Cu1 Ni1 Zn1            FCC
# 274                       120            Co1 Cr1 Cu1 Ni1 Zn1            FCC
# 275                       120            Co1 Cr1 Cu1 Ni1 Zn1            FCC
# 276                       130                Co1 Cr1 Fe1 Ni1            FCC
#
#     PROPERTY: Processing method  PROPERTY: grain size ($\mu$m)  \
# 0                          CAST                            NaN
# 1                           NaN                            NaN
# 2                        POWDER                       500.0000
# 3                          CAST                            NaN
# 4                        POWDER                         0.0182
# ..                          ...                            ...
# 272                        CAST                            NaN
# 273                      POWDER                       500.0000
# 274                      POWDER                       500.0000
# 275                      POWDER                       500.0000
# 276                      POWDER                         0.0276
#
#      PROPERTY: ROM Density (g/cm$^3$)  PROPERTY: Exp. Density (g/cm$^3$)  \
# 0                                 NaN                                NaN
# 1                                 NaN                                NaN
# 2                                 NaN                               7.89
# 3                                 5.7                                NaN
# 4                                 NaN                               8.39
# ..                                ...                                ...
# 272                               NaN                                NaN
# 273                               NaN                               5.26
# 274                               NaN                               6.26
# 275                               NaN                               7.84
# 276                               NaN                                NaN
#
#      PROPERTY: HV PROPERTY: Type of test  \
# 0            94.7                    NaN
# 1           733.0                    NaN
# 2           615.0                      C
# 3           537.0                      C
# 4           531.0                    NaN
# ..            ...                    ...
# 272           NaN                      C
# 273           NaN                      C
# 274           NaN                      C
# 275           NaN                      C
# 276           NaN                    NaN
#
#      PROPERTY: Test temperature ($^\circ$C)  PROPERTY: YS (MPa)  \
# 0                                       NaN                 NaN
# 1                                       NaN                 NaN
# 2                                      25.0                 NaN
# 3                                      25.0               300.0
# 4                                       NaN                 NaN
# ..                                      ...                 ...
# 272                                    25.0               300.0
# 273                                    25.0                 NaN
# 274                                    25.0                 NaN
# 275                                    25.0                 NaN
# 276                                     NaN                 NaN
#
#      PROPERTY: UTS (MPa)  PROPERTY: Elongation (%)  \
# 0                    NaN                       NaN
# 1                    NaN                       NaN
# 2                    NaN                       NaN
# 3                  536.0                       NaN
# 4                    NaN                       NaN
# ..                   ...                       ...
# 272                  NaN                      50.2
# 273                  NaN                       NaN
# 274                  NaN                       NaN
# 275                  NaN                       NaN
# 276                  NaN                       NaN
#
#      PROPERTY: Elongation plastic (%)  PROPERTY: Young modulus (GPa)  \
# 0                                 NaN                            NaN
# 1                                 NaN                            NaN
# 2                                 NaN                            NaN
# 3                                0.85                          108.0
# 4                                 NaN                            NaN
# ..                                ...                            ...
# 272                               NaN                            NaN
# 273                               NaN                            NaN
# 274                               NaN                            NaN
# 275                               NaN                            NaN
# 276                               NaN                            NaN
#
#      PROPERTY: O content (wppm) PROPERTY: N content (wppm)  \
# 0                           NaN                        NaN
# 1                           NaN                        NaN
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                           NaN                        NaN
# ..                          ...                        ...
# 272                         NaN                        NaN
# 273                         NaN                        NaN
# 274                         NaN                        NaN
# 275                         NaN                        NaN
# 276                         NaN                        NaN
#
#      PROPERTY: C content (wppm)                REFERENCE: doi  REFERENCE: year
# 0                           NaN  10.1016/j.matdes.2019.107698             2019
# 1                           NaN    10.1016/j.msea.2019.05.056             2019
# 2                           NaN             10.3390/e21020122             2019
# 3                           NaN  10.1016/j.apsusc.2015.07.207             2015
# 4                           NaN       10.3390/coatings9010016             2019
# ..                          ...                           ...              ...
# 272                         NaN     10.1007/s11665-018-3837-1             2019
# 273                         NaN             10.3390/e21020122             2019
# 274                         NaN             10.3390/e21020122             2019
# 275                         NaN             10.3390/e21020122             2019
# 276                         NaN       10.3390/coatings9010016             2019
#
# [277 rows x 20 columns]

# %% [markdown]
# If we want to refer to the data *now*---as it is currently in the pipeline---we need a name to refer to that DataFrame. This is where the *data pronoun* comes in; remember when we ran this line way up above in the setup chunk?
#
# ```
# DF = gr.Intention()
# ```
#
# This assigns the data pronoun to the name `DF`. We can use this to take advantage of the new (shorter) name we gave to the microstructure column:

# %%
(
    df_mpea
    >> gr.tf_rename(
        microstructure="PROPERTY: Microstructure",
    )
    >> gr.tf_filter(
        DF["microstructure"] == "FCC"
    )
)
# Out:
#      IDENTIFIER: Reference ID                        FORMULA microstructure  \
# 0                         137                Co1 Cr1 Fe1 Ni1            FCC
# 1                         209        Al0.5 Co1 Fe1 Ni1 Ti0.5            FCC
# 2                         120            Co1 Cr1 Cu1 Ni1 Zn1            FCC
# 3                          35                Al1 Cu1 Ni1 Ti1            FCC
# 4                         130  C0.429 Co1 Cr1 Fe1 Ni1 W0.429            FCC
# ..                        ...                            ...            ...
# 272                       119            Co1 Cr1 Cu1 Fe1 Ni1            FCC
# 273                       120            Co1 Cr1 Cu1 Ni1 Zn1            FCC
# 274                       120            Co1 Cr1 Cu1 Ni1 Zn1            FCC
# 275                       120            Co1 Cr1 Cu1 Ni1 Zn1            FCC
# 276                       130                Co1 Cr1 Fe1 Ni1            FCC
#
#     PROPERTY: Processing method  PROPERTY: grain size ($\mu$m)  \
# 0                          CAST                            NaN
# 1                           NaN                            NaN
# 2                        POWDER                       500.0000
# 3                          CAST                            NaN
# 4                        POWDER                         0.0182
# ..                          ...                            ...
# 272                        CAST                            NaN
# 273                      POWDER                       500.0000
# 274                      POWDER                       500.0000
# 275                      POWDER                       500.0000
# 276                      POWDER                         0.0276
#
#      PROPERTY: ROM Density (g/cm$^3$)  PROPERTY: Exp. Density (g/cm$^3$)  \
# 0                                 NaN                                NaN
# 1                                 NaN                                NaN
# 2                                 NaN                               7.89
# 3                                 5.7                                NaN
# 4                                 NaN                               8.39
# ..                                ...                                ...
# 272                               NaN                                NaN
# 273                               NaN                               5.26
# 274                               NaN                               6.26
# 275                               NaN                               7.84
# 276                               NaN                                NaN
#
#      PROPERTY: HV PROPERTY: Type of test  \
# 0            94.7                    NaN
# 1           733.0                    NaN
# 2           615.0                      C
# 3           537.0                      C
# 4           531.0                    NaN
# ..            ...                    ...
# 272           NaN                      C
# 273           NaN                      C
# 274           NaN                      C
# 275           NaN                      C
# 276           NaN                    NaN
#
#      PROPERTY: Test temperature ($^\circ$C)  PROPERTY: YS (MPa)  \
# 0                                       NaN                 NaN
# 1                                       NaN                 NaN
# 2                                      25.0                 NaN
# 3                                      25.0               300.0
# 4                                       NaN                 NaN
# ..                                      ...                 ...
# 272                                    25.0               300.0
# 273                                    25.0                 NaN
# 274                                    25.0                 NaN
# 275                                    25.0                 NaN
# 276                                     NaN                 NaN
#
#      PROPERTY: UTS (MPa)  PROPERTY: Elongation (%)  \
# 0                    NaN                       NaN
# 1                    NaN                       NaN
# 2                    NaN                       NaN
# 3                  536.0                       NaN
# 4                    NaN                       NaN
# ..                   ...                       ...
# 272                  NaN                      50.2
# 273                  NaN                       NaN
# 274                  NaN                       NaN
# 275                  NaN                       NaN
# 276                  NaN                       NaN
#
#      PROPERTY: Elongation plastic (%)  PROPERTY: Young modulus (GPa)  \
# 0                                 NaN                            NaN
# 1                                 NaN                            NaN
# 2                                 NaN                            NaN
# 3                                0.85                          108.0
# 4                                 NaN                            NaN
# ..                                ...                            ...
# 272                               NaN                            NaN
# 273                               NaN                            NaN
# 274                               NaN                            NaN
# 275                               NaN                            NaN
# 276                               NaN                            NaN
#
#      PROPERTY: O content (wppm) PROPERTY: N content (wppm)  \
# 0                           NaN                        NaN
# 1                           NaN                        NaN
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                           NaN                        NaN
# ..                          ...                        ...
# 272                         NaN                        NaN
# 273                         NaN                        NaN
# 274                         NaN                        NaN
# 275                         NaN                        NaN
# 276                         NaN                        NaN
#
#      PROPERTY: C content (wppm)                REFERENCE: doi  REFERENCE: year
# 0                           NaN  10.1016/j.matdes.2019.107698             2019
# 1                           NaN    10.1016/j.msea.2019.05.056             2019
# 2                           NaN             10.3390/e21020122             2019
# 3                           NaN  10.1016/j.apsusc.2015.07.207             2015
# 4                           NaN       10.3390/coatings9010016             2019
# ..                          ...                           ...              ...
# 272                         NaN     10.1007/s11665-018-3837-1             2019
# 273                         NaN             10.3390/e21020122             2019
# 274                         NaN             10.3390/e21020122             2019
# 275                         NaN             10.3390/e21020122             2019
# 276                         NaN       10.3390/coatings9010016             2019
#
# [277 rows x 20 columns]

# %% [markdown]
# Together, the pipe operator `>>` and the data pronoun `DF` form a powerful team that helps us do sophisticated data operations.

# %% [markdown]
# ### __qX__

# %%
## TODO: Eliminate the intermediate variables by using the data pronoun

# %% [markdown]
# ## Back to Verbs
#
# ---

# %% [markdown]
# ### Filtering
#
# TODO

# %% [markdown]
# ### __qX__

# %%
print("Original shape: {}".format(df_mpea.shape))

(
    df_mpea
    >> gr.tf_filter(gr.not_nan(DF["PROPERTY: YS (MPa)"]))
)
# Out:
# Original shape: (1653, 20)
#       IDENTIFIER: Reference ID                                      FORMULA  \
# 0                          146                        Cr1 Mo1 Nb1 Ta1 V1 W1
# 1                          146                        Cr1 Mo1 Nb1 Ta1 V1 W1
# 2                          181  Al0.667 Co0.833 Cr0.833 Fe0.833 Ni0.833 Ti1
# 3                           19                        Al1 Cr1 Fe1 Mo0.8 Ni1
# 4                          186                           Cr1 Fe1 Mo1 Nb1 V1
# ...                        ...                                          ...
# 1141                       132                          Hf1 Nb1 Ta1 Ti1 Zr1
# 1142                       132                          Hf1 Nb1 Ta1 Ti1 Zr1
# 1143                       132                          Hf1 Nb1 Ta1 Ti1 Zr1
# 1144                       133                         Al1 Nb1 Ti1 V1 Zr0.5
# 1145                       133                              Hf1 Nb1 Ti1 Zr1
#
#      PROPERTY: Microstructure PROPERTY: Processing method  \
# 0                         NaN                      POWDER
# 1                         NaN                      POWDER
# 2                         NaN                        CAST
# 3                     B2+Sec.                        CAST
# 4                         NaN                        CAST
# ...                       ...                         ...
# 1141                      BCC                       OTHER
# 1142                      BCC                       OTHER
# 1143                      BCC                       OTHER
# 1144                      NaN                         NaN
# 1145                      NaN                         NaN
#
#       PROPERTY: grain size ($\mu$m)  PROPERTY: ROM Density (g/cm$^3$)  \
# 0                              5.01                               NaN
# 1                             10.80                               NaN
# 2                             22.03                               NaN
# 3                               NaN                               7.0
# 4                               NaN                               NaN
# ...                             ...                               ...
# 1141                          24.40                               NaN
# 1142                          31.30                               NaN
# 1143                          38.40                               NaN
# 1144                            NaN                               NaN
# 1145                            NaN                               NaN
#
#       PROPERTY: Exp. Density (g/cm$^3$)  PROPERTY: HV PROPERTY: Type of test  \
# 0                                   NaN         991.3                      C
# 1                                   NaN         988.3                      C
# 2                                   NaN         856.9                      C
# 3                                   NaN         854.0                      C
# 4                                   NaN         826.0                      C
# ...                                 ...           ...                    ...
# 1141                                NaN           NaN                      T
# 1142                                NaN           NaN                      T
# 1143                                NaN           NaN                      T
# 1144                               5.64           NaN                      C
# 1145                                NaN           NaN                      C
#
#       PROPERTY: Test temperature ($^\circ$C)  PROPERTY: YS (MPa)  \
# 0                                       25.0              3410.0
# 1                                       25.0              3338.0
# 2                                       25.0              1272.0
# 3                                       25.0              1513.0
# 4                                       25.0              2663.0
# ...                                      ...                 ...
# 1141                                    25.0              1107.0
# 1142                                    25.0              1115.0
# 1143                                    25.0              1114.0
# 1144                                    25.0              1480.0
# 1145                                    25.0               879.0
#
#       PROPERTY: UTS (MPa)  PROPERTY: Elongation (%)  \
# 0                     NaN                      2.00
# 1                     NaN                      1.90
# 2                     NaN                      3.15
# 3                  1513.0                       NaN
# 4                     NaN                      2.70
# ...                   ...                       ...
# 1141                977.0                     13.90
# 1142                830.0                     18.50
# 1143                935.0                     12.20
# 1144                  NaN                     50.00
# 1145                  NaN                     16.50
#
#       PROPERTY: Elongation plastic (%)  PROPERTY: Young modulus (GPa)  \
# 0                                  NaN                            NaN
# 1                                  NaN                            NaN
# 2                                  NaN                            NaN
# 3                                  0.0                            NaN
# 4                                  NaN                            NaN
# ...                                ...                            ...
# 1141                               NaN                           92.6
# 1142                               NaN                           92.6
# 1143                               NaN                          101.3
# 1144                               NaN                            NaN
# 1145                               NaN                            NaN
#
#       PROPERTY: O content (wppm) PROPERTY: N content (wppm)  \
# 0                         7946.0                        NaN
# 1                         7946.0                        NaN
# 2                            NaN                        NaN
# 3                            NaN                        NaN
# 4                            NaN                        NaN
# ...                          ...                        ...
# 1141                         NaN                        NaN
# 1142                         NaN                        NaN
# 1143                         NaN                        NaN
# 1144                         NaN                        NaN
# 1145                         NaN                        NaN
#
#       PROPERTY: C content (wppm)                 REFERENCE: doi  \
# 0                            NaN  10.1016/j.jallcom.2018.11.318
# 1                            NaN  10.1016/j.jallcom.2018.11.318
# 2                            NaN  10.1016/j.jallcom.2019.07.100
# 3                            NaN  10.1016/j.jallcom.2013.03.253
# 4                            NaN     10.1007/s40195-019-00935-x
# ...                          ...                            ...
# 1141                         NaN      10.1007/s11661-018-4646-8
# 1142                         NaN      10.1007/s11661-018-4646-8
# 1143                         NaN      10.1007/s11661-018-4646-8
# 1144                         NaN  10.1080/02670836.2018.1446267
# 1145                         NaN  10.1080/02670836.2018.1446267
#
#       REFERENCE: year
# 0                2018
# 1                2018
# 2                2019
# 3                2013
# 4                2019
# ...               ...
# 1141             2019
# 1142             2019
# 1143             2019
# 1144             2018
# 1145             2018
#
# [1146 rows x 20 columns]

# %% [markdown]
# ### Mutating
#
# TODO

# %%
(
    df_mpea
    >> gr.tf_mutate(
        E_MPa = DF["PROPERTY: Young modulus (GPa)"] * 1000
    )
    >> gr.tf_filter(gr.not_nan(DF.E_MPa))
)
# Out:
#      IDENTIFIER: Reference ID                         FORMULA  \
# 0                          15  Co1 Cr1 Fe1 Mo1 Ni1 Ti1 V1 Zr1
# 1                          15          Al1 Fe1 Ni1 Ti1 V1 Zr1
# 2                          15      Al1 Co1 Fe1 Ni1 Ti1 V1 Zr1
# 3                          26         Al1 Co1 Cu1 Fe1 Ni1 Si1
# 4                          15  Co1 Cr1 Cu1 Fe1 Ni1 Ti1 V1 Zr1
# ..                        ...                             ...
# 385                       132             Hf1 Nb1 Ta1 Ti1 Zr1
# 386                       132             Hf1 Nb1 Ta1 Ti1 Zr1
# 387                       132             Hf1 Nb1 Ta1 Ti1 Zr1
# 388                       132             Hf1 Nb1 Ta1 Ti1 Zr1
# 389                       132             Hf1 Nb1 Ta1 Ti1 Zr1
#
#     PROPERTY: Microstructure PROPERTY: Processing method  \
# 0                        NaN                        CAST
# 1                        BCC                        CAST
# 2                        BCC                        CAST
# 3                    FCC+BCC                        CAST
# 4                        NaN                        CAST
# ..                       ...                         ...
# 385                      BCC                       OTHER
# 386                      BCC                       OTHER
# 387                      BCC                       OTHER
# 388                      BCC                       OTHER
# 389                      BCC                       OTHER
#
#      PROPERTY: grain size ($\mu$m)  PROPERTY: ROM Density (g/cm$^3$)  \
# 0                              NaN                               7.3
# 1                              NaN                               5.9
# 2                              NaN                               6.2
# 3                              NaN                               5.9
# 4                              NaN                               7.1
# ..                             ...                               ...
# 385                            NaN                               NaN
# 386                            NaN                               NaN
# 387                           24.4                               NaN
# 388                           31.3                               NaN
# 389                           38.4                               NaN
#
#      PROPERTY: Exp. Density (g/cm$^3$)  PROPERTY: HV PROPERTY: Type of test  \
# 0                                  NaN         850.0                    NaN
# 1                                  NaN         800.0                    NaN
# 2                                  NaN         790.0                    NaN
# 3                                  NaN         682.0                    NaN
# 4                                  NaN         680.0                    NaN
# ..                                 ...           ...                    ...
# 385                                NaN           NaN                      T
# 386                                NaN           NaN                      T
# 387                                NaN           NaN                      T
# 388                                NaN           NaN                      T
# 389                                NaN           NaN                      T
#
#      PROPERTY: Test temperature ($^\circ$C)  ...  PROPERTY: UTS (MPa)  \
# 0                                      25.0  ...                  NaN
# 1                                      25.0  ...                  NaN
# 2                                      25.0  ...                  NaN
# 3                                      25.0  ...                  NaN
# 4                                      25.0  ...                  NaN
# ..                                      ...  ...                  ...
# 385                                    25.0  ...               1066.0
# 386                                    25.0  ...                964.0
# 387                                    25.0  ...                977.0
# 388                                    25.0  ...                830.0
# 389                                    25.0  ...                935.0
#
#      PROPERTY: Elongation (%)  PROPERTY: Elongation plastic (%)  \
# 0                         NaN                               NaN
# 1                         NaN                               NaN
# 2                         NaN                               NaN
# 3                         NaN                               NaN
# 4                         NaN                               NaN
# ..                        ...                               ...
# 385                       6.0                               NaN
# 386                       4.6                               NaN
# 387                      13.9                               NaN
# 388                      18.5                               NaN
# 389                      12.2                               NaN
#
#      PROPERTY: Young modulus (GPa)  PROPERTY: O content (wppm)  \
# 0                            193.0                         NaN
# 1                            132.0                         NaN
# 2                            143.0                         NaN
# 3                            145.0                         NaN
# 4                            168.0                         NaN
# ..                             ...                         ...
# 385                          105.3                         NaN
# 386                           91.6                         NaN
# 387                           92.6                         NaN
# 388                           92.6                         NaN
# 389                          101.3                         NaN
#
#      PROPERTY: N content (wppm) PROPERTY: C content (wppm)  \
# 0                           NaN                        NaN
# 1                           NaN                        NaN
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                           NaN                        NaN
# ..                          ...                        ...
# 385                         NaN                        NaN
# 386                         NaN                        NaN
# 387                         NaN                        NaN
# 388                         NaN                        NaN
# 389                         NaN                        NaN
#
#                  REFERENCE: doi REFERENCE: year     E_MPa
# 0        10.1002/adem.200300567            2004  193000.0
# 1        10.1002/adem.200300567            2004  132000.0
# 2        10.1002/adem.200300567            2004  143000.0
# 3    10.1016/j.msea.2012.07.003            2012  145000.0
# 4        10.1002/adem.200300567            2004  168000.0
# ..                          ...             ...       ...
# 385   10.1007/s11661-018-4646-8            2019  105300.0
# 386   10.1007/s11661-018-4646-8            2019   91600.0
# 387   10.1007/s11661-018-4646-8            2019   92600.0
# 388   10.1007/s11661-018-4646-8            2019   92600.0
# 389   10.1007/s11661-018-4646-8            2019  101300.0
#
# [390 rows x 21 columns]

# %% [markdown]
# ## Pivoting Data
#
# ---
#
# TODO

# %%
from grama.data import df_stang_wide
df_stang_wide
# Out:
#    thick   E_00  mu_00   E_45  mu_45   E_90  mu_90     alloy
# 0  0.022  10600  0.321  10700  0.329  10500  0.310   al_24st
# 1  0.022  10600  0.323  10500  0.331  10700  0.323   al_24st
# 2  0.032  10400  0.329  10400  0.318  10300  0.322   al_24st
# 3  0.032  10300  0.319  10500  0.326  10400  0.330   al_24st
# 4  0.064  10500  0.323  10400  0.331  10400  0.327   al_24st
# 5  0.064  10700  0.328  10500  0.328  10500  0.320   al_24st
# 6  0.081  10000  0.315  10000  0.320   9900  0.314   al_24st
# 7  0.081  10100  0.312   9900  0.312  10000  0.316   al_24st
# 8  0.081  10000  0.311     -1 -1.000   9900  0.314   al_24st

# %% [markdown]
# Our goal will be to wrangle this messy, wide dataset into tidy, long format.

# %%
from grama.data import df_stang
df_stang
# Out:
#     thick     alloy      E     mu  ang
# 0   0.022   al_24st  10600  0.321    0
# 1   0.022   al_24st  10600  0.323    0
# 2   0.032   al_24st  10400  0.329    0
# 3   0.032   al_24st  10300  0.319    0
# 4   0.064   al_24st  10500  0.323    0
# ..    ...       ...    ...    ...  ...
# 71  0.064   al_24st  10400  0.327   90
# 72  0.064   al_24st  10500  0.320   90
# 73  0.081   al_24st   9900  0.314   90
# 74  0.081   al_24st  10000  0.316   90
# 75  0.081   al_24st   9900  0.314   90
#
# [76 rows x 5 columns]

# %% [markdown]
# (What does pivoting look like? Here's an example.)

# %%
df_tmp = (
    gr.df_make(
        A=[1, 2, 3],
        B=[4, 5, 6],
        C=[7, 8, 9],
    )
)
print(df_tmp)

(
    df_tmp
    >> gr.tf_pivot_longer(
        columns=["A", "B", "C"],
        names_to="name",
        values_to="value",
    )
)
# Out:
#    A  B  C
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9
#   name  value
# 0    A      1
# 1    A      2
# 2    A      3
# 3    B      4
# 4    B      5
# 5    B      6
# 6    C      7
# 7    C      8
# 8    C      9

# %% [markdown]
# ### __QX__
#
# (Make sure to add an `observation` column with the `index_to` argument.)

# %%
# solution-begin
df_qX = (
    df_stang_wide
    >> gr.tf_pivot_longer(
        columns=["E_00", "mu_00", "E_45", "mu_45", "E_90", "mu_90"],
        names_to="name",
        values_to="value",
        index_to="observation",
    )
)
# solution-end
df_qX
# Out:
# Warning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     observation  thick     alloy   name      value
# 0             0  0.022   al_24st   E_00  10600.000
# 1             1  0.022   al_24st   E_00  10600.000
# 2             2  0.032   al_24st   E_00  10400.000
# 3             3  0.032   al_24st   E_00  10300.000
# 4             4  0.064   al_24st   E_00  10500.000
# 5             5  0.064   al_24st   E_00  10700.000
# 6             6  0.081   al_24st   E_00  10000.000
# 7             7  0.081   al_24st   E_00  10100.000
# 8             8  0.081   al_24st   E_00  10000.000
# 9             0  0.022   al_24st  mu_00      0.321
# 10            1  0.022   al_24st  mu_00      0.323
# 11            2  0.032   al_24st  mu_00      0.329
# 12            3  0.032   al_24st  mu_00      0.319
# 13            4  0.064   al_24st  mu_00      0.323
# 14            5  0.064   al_24st  mu_00      0.328
# 15            6  0.081   al_24st  mu_00      0.315
# 16            7  0.081   al_24st  mu_00      0.312
# 17            8  0.081   al_24st  mu_00      0.311
# 18            0  0.022   al_24st   E_45  10700.000
# 19            1  0.022   al_24st   E_45  10500.000
# 20            2  0.032   al_24st   E_45  10400.000
# 21            3  0.032   al_24st   E_45  10500.000
# 22            4  0.064   al_24st   E_45  10400.000
# 23            5  0.064   al_24st   E_45  10500.000
# 24            6  0.081   al_24st   E_45  10000.000
# 25            7  0.081   al_24st   E_45   9900.000
# 26            8  0.081   al_24st   E_45     -1.000
# 27            0  0.022   al_24st  mu_45      0.329
# 28            1  0.022   al_24st  mu_45      0.331
# 29            2  0.032   al_24st  mu_45      0.318
# 30            3  0.032   al_24st  mu_45      0.326
# 31            4  0.064   al_24st  mu_45      0.331
# 32            5  0.064   al_24st  mu_45      0.328
# 33            6  0.081   al_24st  mu_45      0.320
# 34            7  0.081   al_24st  mu_45      0.312
# 35            8  0.081   al_24st  mu_45     -1.000
# 36            0  0.022   al_24st   E_90  10500.000
# 37            1  0.022   al_24st   E_90  10700.000
# 38            2  0.032   al_24st   E_90  10300.000
# 39            3  0.032   al_24st   E_90  10400.000
# 40            4  0.064   al_24st   E_90  10400.000
# 41            5  0.064   al_24st   E_90  10500.000
# 42            6  0.081   al_24st   E_90   9900.000
# 43            7  0.081   al_24st   E_90  10000.000
# 44            8  0.081   al_24st   E_90   9900.000
# 45            0  0.022   al_24st  mu_90      0.310
# 46            1  0.022   al_24st  mu_90      0.323
# 47            2  0.032   al_24st  mu_90      0.322
# 48            3  0.032   al_24st  mu_90      0.330
# 49            4  0.064   al_24st  mu_90      0.327
# 50            5  0.064   al_24st  mu_90      0.320
# 51            6  0.081   al_24st  mu_90      0.314
# 52            7  0.081   al_24st  mu_90      0.316
# 53            8  0.081   al_24st  mu_90      0.314

# %% [markdown]
# Execute the following to check your work.

# %%
try:
    assert(df_qX.shape[0] == 54)
except AssertionError:
    raise AssertionError("The DataFrame is not sufficiently long; did you pivot?")
    
try:
    assert(df_qX.shape[1] == 5)
except AssertionError:
    raise AssertionError("The DataFrame should have five columns")
    
try:
    assert("observation" in df_qX.columns)
except AssertionError:
    raise AssertionError("The DataFrame should have five columns")
    
print("Success!")
# Out:
# Success!

# %% [markdown]
# ### __QY__

# %%
df_qY = (
    df_qX
# solution-begin
    >> gr.tf_separate(
        column="name",
        into=["var", "angle"],
        sep="_",
    )
# solution-end
)
df_qY
# Out:
#     observation  thick     alloy      value var angle
# 0             0  0.022   al_24st  10600.000   E    00
# 1             1  0.022   al_24st  10600.000   E    00
# 2             2  0.032   al_24st  10400.000   E    00
# 3             3  0.032   al_24st  10300.000   E    00
# 4             4  0.064   al_24st  10500.000   E    00
# 5             5  0.064   al_24st  10700.000   E    00
# 6             6  0.081   al_24st  10000.000   E    00
# 7             7  0.081   al_24st  10100.000   E    00
# 8             8  0.081   al_24st  10000.000   E    00
# 9             0  0.022   al_24st      0.321  mu    00
# 10            1  0.022   al_24st      0.323  mu    00
# 11            2  0.032   al_24st      0.329  mu    00
# 12            3  0.032   al_24st      0.319  mu    00
# 13            4  0.064   al_24st      0.323  mu    00
# 14            5  0.064   al_24st      0.328  mu    00
# 15            6  0.081   al_24st      0.315  mu    00
# 16            7  0.081   al_24st      0.312  mu    00
# 17            8  0.081   al_24st      0.311  mu    00
# 18            0  0.022   al_24st  10700.000   E    45
# 19            1  0.022   al_24st  10500.000   E    45
# 20            2  0.032   al_24st  10400.000   E    45
# 21            3  0.032   al_24st  10500.000   E    45
# 22            4  0.064   al_24st  10400.000   E    45
# 23            5  0.064   al_24st  10500.000   E    45
# 24            6  0.081   al_24st  10000.000   E    45
# 25            7  0.081   al_24st   9900.000   E    45
# 26            8  0.081   al_24st     -1.000   E    45
# 27            0  0.022   al_24st      0.329  mu    45
# 28            1  0.022   al_24st      0.331  mu    45
# 29            2  0.032   al_24st      0.318  mu    45
# 30            3  0.032   al_24st      0.326  mu    45
# 31            4  0.064   al_24st      0.331  mu    45
# 32            5  0.064   al_24st      0.328  mu    45
# 33            6  0.081   al_24st      0.320  mu    45
# 34            7  0.081   al_24st      0.312  mu    45
# 35            8  0.081   al_24st     -1.000  mu    45
# 36            0  0.022   al_24st  10500.000   E    90
# 37            1  0.022   al_24st  10700.000   E    90
# 38            2  0.032   al_24st  10300.000   E    90
# 39            3  0.032   al_24st  10400.000   E    90
# 40            4  0.064   al_24st  10400.000   E    90
# 41            5  0.064   al_24st  10500.000   E    90
# 42            6  0.081   al_24st   9900.000   E    90
# 43            7  0.081   al_24st  10000.000   E    90
# 44            8  0.081   al_24st   9900.000   E    90
# 45            0  0.022   al_24st      0.310  mu    90
# 46            1  0.022   al_24st      0.323  mu    90
# 47            2  0.032   al_24st      0.322  mu    90
# 48            3  0.032   al_24st      0.330  mu    90
# 49            4  0.064   al_24st      0.327  mu    90
# 50            5  0.064   al_24st      0.320  mu    90
# 51            6  0.081   al_24st      0.314  mu    90
# 52            7  0.081   al_24st      0.316  mu    90
# 53            8  0.081   al_24st      0.314  mu    90

# %%
try:
    assert(df_qY.shape[0] == 54)
except AssertionError:
    raise AssertionError("The DataFrame is not the right length; how did that happen?")
    
try:
    assert(df_qY.shape[1] == 6)
except AssertionError:
    raise AssertionError("The DataFrame should have six columns")
    
try:
    assert("angle" in df_qY.columns)
except AssertionError:
    raise AssertionError("The DataFrame should have an 'angle' column")
    
print("Success!")
# Out:
# Success!

# %% [markdown]
# ### __QZ__
#
# *Hint*: You should only need to set the `names_from` and `values_from` arguments with this function.

# %%
df_qZ = (
    df_qY
# solution-begin
    >> gr.tf_pivot_wider(
        names_from="var",
        values_from="value",
    )
# solution-end
)
df_qZ
# Out:
#     observation  thick     alloy angle        E     mu
# 0             0  0.022   al_24st    00  10600.0  0.321
# 1             0  0.022   al_24st    45  10700.0  0.329
# 2             0  0.022   al_24st    90  10500.0  0.310
# 3             1  0.022   al_24st    00  10600.0  0.323
# 4             1  0.022   al_24st    45  10500.0  0.331
# 5             1  0.022   al_24st    90  10700.0  0.323
# 6             2  0.032   al_24st    00  10400.0  0.329
# 7             2  0.032   al_24st    45  10400.0  0.318
# 8             2  0.032   al_24st    90  10300.0  0.322
# 9             3  0.032   al_24st    00  10300.0  0.319
# 10            3  0.032   al_24st    45  10500.0  0.326
# 11            3  0.032   al_24st    90  10400.0  0.330
# 12            4  0.064   al_24st    00  10500.0  0.323
# 13            4  0.064   al_24st    45  10400.0  0.331
# 14            4  0.064   al_24st    90  10400.0  0.327
# 15            5  0.064   al_24st    00  10700.0  0.328
# 16            5  0.064   al_24st    45  10500.0  0.328
# 17            5  0.064   al_24st    90  10500.0  0.320
# 18            6  0.081   al_24st    00  10000.0  0.315
# 19            6  0.081   al_24st    45  10000.0  0.320
# 20            6  0.081   al_24st    90   9900.0  0.314
# 21            7  0.081   al_24st    00  10100.0  0.312
# 22            7  0.081   al_24st    45   9900.0  0.312
# 23            7  0.081   al_24st    90  10000.0  0.316
# 24            8  0.081   al_24st    00  10000.0  0.311
# 25            8  0.081   al_24st    45     -1.0 -1.000
# 26            8  0.081   al_24st    90   9900.0  0.314

# %%
try:
    assert(df_qZ.shape[0] == 27)
except AssertionError:
    raise AssertionError("The DataFrame is not the right length; how did that happen?")
    
try:
    assert("angle" in df_qZ.columns)
except AssertionError:
    raise AssertionError("The DataFrame should have an 'angle' column")
    
try:
    assert("E" in df_qZ.columns)
except AssertionError:
    raise AssertionError("The DataFrame should have an 'E' column")
    
try:
    assert("mu" in df_qZ.columns)
except AssertionError:
    raise AssertionError("The DataFrame should have an 'mu' column")
    
print("Success!")
# Out:
# Success!

# %% [markdown]
# ### Bonus: One-step pivot

# %%
(
    df_stang_wide
    >> gr.tf_pivot_longer(
        columns=["E_00", "mu_00", "E_45", "mu_45", "E_90", "mu_90"],
        names_to=[".value", "angle"],
        names_sep="_",
        values_to="value",
    )
)
# Out:
# Warning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     thick     alloy angle        E     mu
# 0   0.022   al_24st    00  10600.0  0.321
# 1   0.022   al_24st    45  10700.0  0.329
# 2   0.022   al_24st    90  10500.0  0.310
# 3   0.022   al_24st    00  10600.0  0.323
# 4   0.022   al_24st    45  10500.0  0.331
# 5   0.022   al_24st    90  10700.0  0.323
# 6   0.032   al_24st    00  10400.0  0.329
# 7   0.032   al_24st    45  10400.0  0.318
# 8   0.032   al_24st    90  10300.0  0.322
# 9   0.032   al_24st    00  10300.0  0.319
# 10  0.032   al_24st    45  10500.0  0.326
# 11  0.032   al_24st    90  10400.0  0.330
# 12  0.064   al_24st    00  10500.0  0.323
# 13  0.064   al_24st    45  10400.0  0.331
# 14  0.064   al_24st    90  10400.0  0.327
# 15  0.064   al_24st    00  10700.0  0.328
# 16  0.064   al_24st    45  10500.0  0.328
# 17  0.064   al_24st    90  10500.0  0.320
# 18  0.081   al_24st    00  10000.0  0.315
# 19  0.081   al_24st    45  10000.0  0.320
# 20  0.081   al_24st    90   9900.0  0.314
# 21  0.081   al_24st    00  10100.0  0.312
# 22  0.081   al_24st    45   9900.0  0.312
# 23  0.081   al_24st    90  10000.0  0.316
# 24  0.081   al_24st    00  10000.0  0.311
# 25  0.081   al_24st    45     -1.0 -1.000
# 26  0.081   al_24st    90   9900.0  0.314

# %% [markdown]
# ## Wrangling Data
# [Hadley Wickham](http://hadley.nz/) -- author of the `tidyverse` and data science superstar -- notes that "wrangling data is 80% boredom and 20% screaming". To give you a sense of why this stuff is hard (but hopefully avoid the screaming), I'm leaving one of the wrangling steps in the workflow here:

# %% [markdown]
# It's not obvious from the exercises above, but *there's an issue with these data*.

# %%
df_data.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/xv/k5cp232j1cn3y8kym53_nnkc0000gn/T/ipykernel_22801/3658842013.py in <module>
# ----> 1 df_data.dtypes
#
# NameError: name 'df_data' is not defined

# %% [markdown]
# All of the entries are objects, not numbers! We'll need to convert these to numeric values. The following slightly-mysterious call will cast every column of `df_data` to a numeric type and modify the DataFrame.

# %%
df_data = df_data.apply(pd.to_numeric)

# %% [markdown]
# Let's check the data types again:

# %%
df_data.dtypes

# %% [markdown]
# These are numbers we can work with!

# %% [markdown]
# ## Basic DataFrame Operations

# %% [markdown]
# With the numerical issues above sorted out, we can carry out *quantitative* operations on the dataframe. One useful thing we can do is compute a set of *summaries* on the data using `describe()`.

# %%
df_data.describe()

# %% [markdown]
# These summaries include things like the `mean` and standard deviation (`std`), as well as quartiles of the data. These give us a sense of *typical* values; for instance, we can see that a large fraction of observations have a zero-"Diffusion time", but at least one observation has a value `> 70`.

# %% [markdown]
# ### Special indexing
# One of the most powerful features of pandas is the ability to do *logical indexing*; we may provide an array of `True` or `False` values to select only those rows with `True` values. For instance, we could do the following to select the third row.

# %%
idx_boolean = [False] * df_data.shape[0]  # Mostly-false array
idx_boolean[2] = True  # Make the third entry True
df_data[idx_boolean]

# %% [markdown]
# Where this kind of *logical indexing* becomes helpful is when we chain this with the conditionals we learned in the previous exercise. For instance, we could use logic *using one of the columns* to effectively "filter" for variables that meet some condition. For instance, the following will filter for nonzero "Carburization Time".

# %%
df_data[df_data["Carburization Time"] > 0].head()

# %% [markdown]
# ### Q5: Basic data operations
# Once more, use the [pandas documentation](https://pandas.pydata.org/pandas-docs/stable/getting_started/10min.html) to learn how to do the following tasks:
#
# - Select only those rows for which "Diffusion time" is greater than 70
# - Sort df_data in descending order by "Fatigue Strength" and return the top 10
# - Take the average of "Normalizing Temperature" and "Tempering Temperature" and add the column "avg_temp" (You may need to Google how to do this one!)

# %%
###
# TASK: Basic data operations
# TODO: Select rows for which "Diffusion time" > 70
###

# -- WRITE YOUR CODE BELOW -----
# solution-begin
df_data[df_data["Diffusion time"] > 70]
# solution-end

# %%
###
# TASK: Basic data operations
# TODO: Sort by "Fatigue Strength" in descending order, take the top-10
###

# -- WRITE YOUR CODE BELOW -----
# solution-begin
df_data.sort_values(by="Fatigue Strength", ascending=False).head(10)
# solution-end

# %%
###
# TASK: Basic data operations
# TODO: Average "Normalizing Temperature" and "Tempering Temperature" into the column "avg_tmp", return the head
###

# -- WRITE YOUR CODE BELOW -----
# solution-begin
df_data.assign(
    avg_tmp=0.5 * (df_data["Normalizing Temperature"] + df_data["Tempering Temperature"])).head()
# solution-end
